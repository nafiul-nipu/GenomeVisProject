# %%
import os
import numpy as np
import pandas as pd
from scipy.ndimage import gaussian_filter
from skimage.measure import marching_cubes
import trimesh
from sklearn.neighbors import NearestNeighbors

# Load Gene Positions 
def load_gene_positions(csv_path):
    df = pd.read_csv(csv_path)
    return df[['middle_x', 'middle_y', 'middle_z']].dropna().values

# OPTION A: Estimate radius using nearest neighbor distance
def estimate_radius_nnd(points, scale=1.5):
    nbrs = NearestNeighbors(n_neighbors=2).fit(points)
    distances, _ = nbrs.kneighbors(points)
    avg_dist = np.mean(distances[:, 1])
    return avg_dist * scale

# OPTION B: Estimate radius based on point count (volume heuristic)
def estimate_radius_by_count(points, k=5.0):
    n = len(points)
    return k / (n ** (1 / 3))


# Create scalar field via metaball union
def create_metaball_field(points, grid_resolution=100, radius=5.0, grid_margin=10):
    mins = points.min(axis=0) - grid_margin
    maxs = points.max(axis=0) + grid_margin
    dims = (maxs - mins)
    spacing = dims / grid_resolution

    x = np.linspace(mins[0], maxs[0], grid_resolution)
    y = np.linspace(mins[1], maxs[1], grid_resolution)
    z = np.linspace(mins[2], maxs[2], grid_resolution)
    X, Y, Z = np.meshgrid(x, y, z, indexing='ij')
    field = np.zeros_like(X)

    for p in points:
        d2 = (X - p[0])**2 + (Y - p[1])**2 + (Z - p[2])**2
        field += np.exp(-d2 / (2 * radius**2))

    return field, (x, y, z)

# automatically detect marching cube level
def auto_select_level(field, grid_axes, level_range=(0.3, 0.7), steps=10):
    best_level = None
    best_score = -np.inf

    levels = np.linspace(level_range[0], level_range[1], steps)

    for lvl in levels:
        try:
            verts, faces, _, _ = marching_cubes(field, level=lvl)
            surface_area = trimesh.Trimesh(vertices=verts, faces=faces).area
            score = -abs(surface_area - 10000)  # target surface area
            if score > best_score:
                best_score = score
                best_level = lvl
        except Exception:
            continue

    return best_level
    
# Extract surface from scalar field
def extract_metaball_surface(field, grid_axes, level=0.5):
    verts, faces, _, _ = marching_cubes(field, level=level)
    x, y, z = grid_axes
    spacing = [(a[1] - a[0]) for a in grid_axes]
    origin = [a[0] for a in grid_axes]
    verts_world = verts * spacing + origin
    return trimesh.Trimesh(vertices=verts_world, faces=faces, process=False)


# Main Pipeline
def run_metaball_pipeline(csv_path, save_path=None):
    points = load_gene_positions(csv_path)

    # ----- radius methods -----
    # METHOD A: nearest neighbor
    radius = estimate_radius_nnd(points, scale=1.5)    
    # METHOD B: volume-based
    # radius = estimate_radius_by_count(points, k=5.0)       

    print(f"Using radius: {radius:.3f}")

    field, axes = create_metaball_field(points, grid_resolution=150, radius=radius)
    level = auto_select_level(field, axes)
    print(f"Level selected: {level}")
    mesh = extract_metaball_surface(field, axes, level=level)

    if save_path:
        os.makedirs(os.path.dirname(save_path), exist_ok=True)  # <-- Ensure folder exists
        file_type = os.path.splitext(save_path)[-1].replace('.', '')
        mesh.export(save_path, file_type=file_type)
        print(f"Saved mesh to {save_path}")

def main():
    base_dir = "data/green_monkey/all_structure_files/"
    for chrom in os.listdir(base_dir):
        chrom_path = os.path.join(base_dir, chrom)
        if not os.path.isdir(chrom_path):
            continue
        print(f"Processing {chrom}...")
        for hrs in os.listdir(chrom_path):
            hrs_path = os.path.join(chrom_path, hrs)
            if not os.path.isdir(hrs_path):
                continue
            for cond in ['vacv', 'untr']:
                cond_path = os.path.join(hrs_path, cond)
                if not os.path.isdir(cond_path):
                    continue
    
                fp = os.path.join(cond_path, f'structure_{hrs}_{cond}_gene_info.csv')
                if not os.path.exists(fp):
                    continue
                print(fp)
                out_dir = os.path.join(base_dir, chrom, 'spatial_data', 'overall_shapes')
                os.makedirs(out_dir, exist_ok=True)  # <-- Create folder if missing
                obj_path = os.path.join(out_dir, f"{chrom}_{hrs}_{cond}_metaball.obj")

                run_metaball_pipeline(fp, save_path=obj_path)

if __name__ == "__main__":
    main()
    
# # ---- Run ----
# csv_path = "data/green_monkey/all_structure_files/chr1/24hrs/vacv/structure_24hrs_vacv_gene_info.csv"
# obj_path = "data/green_monkey/all_structure_files/chr1/spatial_data/chr1_24hrs_vacv_metaball.obj"

# run_metaball_pipeline(csv_path, view=True, save_path=obj_path)
# Out:
# Processing chr23...
# data/green_monkey/all_structure_files/chr23/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.302
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr23/spatial_data/overall_shapes/chr23_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr23/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.305
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr23/spatial_data/overall_shapes/chr23_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr23/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.316
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr23/spatial_data/overall_shapes/chr23_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr23/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.310
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr23/spatial_data/overall_shapes/chr23_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr23/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.316
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr23/spatial_data/overall_shapes/chr23_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr23/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.336
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr23/spatial_data/overall_shapes/chr23_18hrs_untr_metaball.obj
# Processing chr12...
# data/green_monkey/all_structure_files/chr12/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.294
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr12/spatial_data/overall_shapes/chr12_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr12/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.301
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr12/spatial_data/overall_shapes/chr12_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr12/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.314
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr12/spatial_data/overall_shapes/chr12_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr12/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.301
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr12/spatial_data/overall_shapes/chr12_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr12/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.314
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr12/spatial_data/overall_shapes/chr12_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr12/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.326
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr12/spatial_data/overall_shapes/chr12_18hrs_untr_metaball.obj
# Processing chr15...
# data/green_monkey/all_structure_files/chr15/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.335
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr15/spatial_data/overall_shapes/chr15_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr15/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.338
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr15/spatial_data/overall_shapes/chr15_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr15/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.372
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr15/spatial_data/overall_shapes/chr15_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr15/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.374
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr15/spatial_data/overall_shapes/chr15_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr15/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.374
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr15/spatial_data/overall_shapes/chr15_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr15/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.368
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr15/spatial_data/overall_shapes/chr15_18hrs_untr_metaball.obj
# Processing chr14...
# data/green_monkey/all_structure_files/chr14/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.279
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr14/spatial_data/overall_shapes/chr14_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr14/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.289
# Level selected: 0.7
# Saved mesh to data/green_monkey/all_structure_files/chr14/spatial_data/overall_shapes/chr14_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr14/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.289
# Level selected: 0.7
# Saved mesh to data/green_monkey/all_structure_files/chr14/spatial_data/overall_shapes/chr14_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr14/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.295
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr14/spatial_data/overall_shapes/chr14_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr14/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.296
# Level selected: 0.7
# Saved mesh to data/green_monkey/all_structure_files/chr14/spatial_data/overall_shapes/chr14_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr14/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.305
# Level selected: 0.7
# Saved mesh to data/green_monkey/all_structure_files/chr14/spatial_data/overall_shapes/chr14_18hrs_untr_metaball.obj
# Processing chr13...
# data/green_monkey/all_structure_files/chr13/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.342
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr13/spatial_data/overall_shapes/chr13_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr13/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.340
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr13/spatial_data/overall_shapes/chr13_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr13/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.360
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr13/spatial_data/overall_shapes/chr13_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr13/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.344
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr13/spatial_data/overall_shapes/chr13_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr13/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.375
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr13/spatial_data/overall_shapes/chr13_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr13/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.370
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr13/spatial_data/overall_shapes/chr13_18hrs_untr_metaball.obj
# Processing chr25...
# data/green_monkey/all_structure_files/chr25/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.300
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr25/spatial_data/overall_shapes/chr25_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr25/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.310
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr25/spatial_data/overall_shapes/chr25_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr25/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.324
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr25/spatial_data/overall_shapes/chr25_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr25/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.311
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr25/spatial_data/overall_shapes/chr25_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr25/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.320
# Level selected: 0.7
# Saved mesh to data/green_monkey/all_structure_files/chr25/spatial_data/overall_shapes/chr25_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr25/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.325
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/ch
12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr27/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.404
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr27/spatial_data/overall_shapes/chr27_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr27/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.420
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr27/spatial_data/overall_shapes/chr27_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr27/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.404
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr27/spatial_data/overall_shapes/chr27_18hrs_untr_metaball.obj
# Processing chr20...
# data/green_monkey/all_structure_files/chr20/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.244
# Level selected: 0.7
# Saved mesh to data/green_monkey/all_structure_files/chr20/spatial_data/overall_shapes/chr20_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr20/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.259
# Level selected: 0.6555555555555554
# Saved mesh to data/green_monkey/all_structure_files/chr20/spatial_data/overall_shapes/chr20_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr20/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.267
# Level selected: 0.7
# Saved mesh to data/green_monkey/all_structure_files/chr20/spatial_data/overall_shapes/chr20_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr20/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.259
# Level selected: 0.7
# Saved mesh to data/green_monkey/all_structure_files/chr20/spatial_data/overall_shapes/chr20_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr20/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.268
# Level selected: 0.611111111111111
# Saved mesh to data/green_monkey/all_structure_files/chr20/spatial_data/overall_shapes/chr20_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr20/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.272
# Level selected: 0.611111111111111
# Saved mesh to data/green_monkey/all_structure_files/chr20/spatial_data/overall_shapes/chr20_18hrs_untr_metaball.obj
# Processing chr29...
# data/green_monkey/all_structure_files/chr29/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.235
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr29/spatial_data/overall_shapes/chr29_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr29/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.250
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr29/spatial_data/overall_shapes/chr29_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr29/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.248
# Level selected: 0.5222222222222221
# Saved mesh to data/green_monkey/all_structure_files/chr29/spatial_data/overall_shapes/chr29_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr29/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.257
# Level selected: 0.4333333333333333
# Saved mesh to data/green_monkey/all_structure_files/chr29/spatial_data/overall_shapes/chr29_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr29/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.254
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr29/spatial_data/overall_shapes/chr29_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr29/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.241
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr29/spatial_data/overall_shapes/chr29_18hrs_untr_metaball.obj
# Processing chr16...
# data/green_monkey/all_structure_files/chr16/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.213
# Level selected: 0.5222222222222221
# Saved mesh to data/green_monkey/all_structure_files/chr16/spatial_data/overall_shapes/chr16_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr16/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.216
# Level selected: 0.47777777777777775
# Saved mesh to data/green_monkey/all_structure_files/chr16/spatial_data/overall_shapes/chr16_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr16/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.222
# Level selected: 0.7
# Saved mesh to data/green_monkey/all_structure_files/chr16/spatial_data/overall_shapes/chr16_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr16/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.216
# Level selected: 0.7
# Saved mesh to data/green_monkey/all_structure_files/chr16/spatial_data/overall_shapes/chr16_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr16/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.225
# Level selected: 0.7
# Saved mesh to data/green_monkey/all_structure_files/chr16/spatial_data/overall_shapes/chr16_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr16/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.225
# Level selected: 0.7
# Saved mesh to data/green_monkey/all_structure_files/chr16/spatial_data/overall_shapes/chr16_18hrs_untr_metaball.obj
# Processing chr10...
# data/green_monkey/all_structure_files/chr10/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.296
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr10/spatial_data/overall_shapes/chr10_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr10/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.311
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr10/spatial_data/overall_shapes/chr10_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr10/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.320
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr10/spatial_data/overall_shapes/chr10_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr10/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.319
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr10/spatial_data/overall_shapes/chr10_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr10/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.321
# Level selected: 0.38888888888888884
# Saved mesh to data/green_monkey/all_structure_files/chr10/spatial_data/overall_shapes/chr10_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr10/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.336
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr10/spatial_data/overall_shapes/chr10_18hrs_untr_metaball.obj
# Processing chr28...
# data/green_monkey/all_structure_files/chr28/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.279
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr28/spatial_data/overall_shapes/chr28_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr28/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.282
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr28/spatial_data/overall_shapes/chr28_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr28/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.272
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr28/spatial_data/overall_shapes/chr28_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr28/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.281
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr28/spatial_data/overall_shapes/chr28_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr28/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.289
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr28/spatial_data/overall_shapes/chr28_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr28/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.294
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr28/spatial_data/overall_shapes/chr28_18hrs_untr_metaball.obj
# Processing chr21...
# data/green_monkey/all_structure_files/chr21/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.298
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr21/spatial_data/overall_shapes/chr21_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr21/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.323
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr21/spatial_data/overall_shapes/chr21_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr21/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.328
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr21/spatial_data/overall_shapes/chr21_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr21/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.315
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr21/spatial_data/overall_shapes/chr21_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr21/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.325
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr21/spatial_data/overall_shapes/chr21_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr21/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.326
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr21/spatial_data/overall_shapes/chr21_18hrs_untr_metaball.obj
# Processing chr19...
# data/green_monkey/all_structure_files/chr19/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.234
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr19/spatial_data/overall_shapes/chr19_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr19/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.243
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr19/spatial_data/overall_shapes/chr19_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr19/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.249
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr19/spatial_data/overall_shapes/chr19_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr19/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.247
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr19/spatial_data/overall_shapes/chr19_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr19/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.247
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr19/spatial_data/overall_shapes/chr19_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr19/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.262
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr19/spatial_data/overall_shapes/chr19_18hrs_untr_metaball.obj
# Processing chr26...
# data/green_monkey/all_structure_files/chr26/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.313
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr26/spatial_data/overall_shapes/chr26_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr26/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.314
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr26/spatial_data/overall_shapes/chr26_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr26/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.335
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr26/spatial_data/overall_shapes/chr26_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr26/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.336
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr26/spatial_data/overall_shapes/chr26_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr26/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.340
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr26/spatial_data/overall_shapes/chr26_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr26/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.337
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr26/spatial_data/overall_shapes/chr26_18hrs_untr_metaball.obj
# Processing chr7...
# data/green_monkey/all_structure_files/chr7/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.383
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr7/spatial_data/overall_shapes/chr7_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr7/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.391
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr7/spatial_data/overall_shapes/chr7_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr7/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.407
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr7/spatial_data/overall_shapes/chr7_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr7/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.392
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr7/spatial_data/overall_shapes/chr7_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr7/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.409
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr7/spatial_data/overall_shapes/chr7_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr7/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.406
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr7/spatial_data/overall_shapes/chr7_18hrs_untr_metaball.obj
# Processing chr6...
# data/green_monkey/all_structure_files/chr6/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.200
# Level selected: 0.5666666666666667
# Saved mesh to data/green_monkey/all_structure_files/chr6/spatial_data/overall_shapes/chr6_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr6/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.200
# Level selected: 0.7
# Saved mesh to data/green_monkey/all_structure_files/chr6/spatial_data/overall_shapes/chr6_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr6/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.208
# Level selected: 0.4333333333333333
# Saved mesh to data/green_monkey/all_structure_files/chr6/spatial_data/overall_shapes/chr6_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr6/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.200
# Level selected: 0.611111111111111
# Saved mesh to data/green_monkey/all_structure_files/chr6/spatial_data/overall_shapes/chr6_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr6/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.211
# Level selected: 0.6555555555555554
# Saved mesh to data/green_monkey/all_structure_files/chr6/spatial_data/overall_shapes/chr6_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr6/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.207
# Level selected: 0.611111111111111
# Saved mesh to data/green_monkey/all_structure_files/chr6/spatial_data/overall_shapes/chr6_18hrs_untr_metaball.obj
# Processing chr1...
# data/green_monkey/all_structure_files/chr1/24hrs/vacv/structure_24hrs_vacv_gene_info.csv
# Using radius: 0.250
# Level selected: 0.7
# Saved mesh to data/green_monkey/all_structure_files/chr1/spatial_data/overall_shapes/chr1_24hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr1/24hrs/untr/structure_24hrs_untr_gene_info.csv
# Using radius: 0.254
# Level selected: 0.7
# Saved mesh to data/green_monkey/all_structure_files/chr1/spatial_data/overall_shapes/chr1_24hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr1/12hrs/vacv/structure_12hrs_vacv_gene_info.csv
# Using radius: 0.259
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr1/spatial_data/overall_shapes/chr1_12hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr1/12hrs/untr/structure_12hrs_untr_gene_info.csv
# Using radius: 0.253
# Level selected: 0.6555555555555554
# Saved mesh to data/green_monkey/all_structure_files/chr1/spatial_data/overall_shapes/chr1_12hrs_untr_metaball.obj
# data/green_monkey/all_structure_files/chr1/18hrs/vacv/structure_18hrs_vacv_gene_info.csv
# Using radius: 0.257
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr1/spatial_data/overall_shapes/chr1_18hrs_vacv_metaball.obj
# data/green_monkey/all_structure_files/chr1/18hrs/untr/structure_18hrs_untr_gene_info.csv
# Using radius: 0.269
# Level selected: 0.3
# Saved mesh to data/green_monkey/all_structure_files/chr1/spatial_data/overall_shapes/chr1_18hrs_untr_metaball.obj
