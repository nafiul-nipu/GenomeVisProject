# %%
import json
import re
from pathlib import Path
from typing import List, Dict, Any, Tuple, Optional
import pandas as pd

BASE = Path("data/green_monkey")

# --- Helpers ---

def parse_json_filename(p: Path) -> Optional[Tuple[str, str, str]]:
    """
    Parse 'chr1_12hrs_UNTR_aligned.json' (also tolerates '_alinged').
    Returns (chr, hours, COND) or None.
    """
    pat = r"^(chr\d+)_([0-9]+hrs)_([\w\-]+)_(?:aligned|alinged)\.json$"
    m = re.match(pat, p.name, re.IGNORECASE)
    if not m:
        return None
    chr_name = m.group(1).lower()
    hours = m.group(2).lower()
    cond = m.group(3).upper()
    return chr_name, hours, cond

def csv_path_for(chr_name: str, hours: str, cond_upper: str) -> Path:
    cond_lower = cond_upper.lower()
    return (
        BASE
        / "all_structure_files"
        / chr_name
        / hours
        / cond_lower
        / f"structure_{hours}_{cond_lower}_gene_info.csv"
    )

def load_aligned_json(p: Path) -> Tuple[List[List[float]], List[int]]:
    with open(p, "r") as f:
        j = json.load(f)
    positions = j.get("position") or j.get("positions")
    clusters = j.get("clusters")
    if not isinstance(positions, list) or not isinstance(clusters, list):
        raise ValueError("Missing 'position(s)' or 'clusters'.")
    if not positions or not isinstance(positions[0], (list, tuple)) or len(positions[0]) < 3:
        raise ValueError("'position' must be a list of [x,y,z].")
    return positions, clusters

def merge_to_objects(df: pd.DataFrame, positions: List[List[float]], clusters: List[int]) -> List[Dict[str, Any]]:
    # remove any old position columns if present
    df = df.drop(columns=[c for c in ["pos_x", "pos_y", "pos_z"] if c in df.columns], errors="ignore").reset_index(drop=True)
    n = min(len(df), len(positions), len(clusters))
    if n == 0:
        return []
    if len(df) != len(positions) or len(df) != len(clusters):
        df = df.iloc[:n].copy()
        positions = positions[:n]
        clusters = clusters[:n]
    recs = df.to_dict(orient="records")
    out: List[Dict[str, Any]] = []
    for i in range(n):
        r = dict(recs[i])
        r["aligned_pos"] = [float(positions[i][0]), float(positions[i][1]), float(positions[i][2])]
        r["cluster"] = int(clusters[i])
        out.append(r)
    return out

def write_output_json(out_path: Path, items: List[Dict[str, Any]]) -> None:
    out_path.parent.mkdir(parents=True, exist_ok=True)
    with open(out_path, "w") as f:
        json.dump(items, f, indent=2, separators=(",", ":"))

# --- Discovery ---

aligned_root = BASE / "structure_genes_aligned"
json_candidates = []
if aligned_root.exists():
    json_candidates += list(aligned_root.rglob("*_aligned.json"))
    json_candidates += list(aligned_root.rglob("*_alinged.json"))
# also allow loose files at BASE
json_candidates += list((BASE).glob("*_aligned.json"))
json_candidates += list((BASE).glob("*_alinged.json"))
json_candidates = sorted(set(json_candidates))

# fallback to a known example if none found
if not json_candidates:
    sample = BASE / "chr1_12hrs_UNTR_aligned.json"
    if sample.exists():
        json_candidates = [sample]

# --- Process ---

for jp in json_candidates:
    triplet = parse_json_filename(jp)
    if not triplet:
        continue
    chr_name, hours, cond_upper = triplet
    csvp = csv_path_for(chr_name, hours, cond_upper)
    if not csvp.exists():
        # try best-effort fallback search
        hits = list(BASE.rglob(f"structure_{hours}_{cond_upper.lower()}_gene_info.csv"))
        if hits:
            csvp = hits[0]
    try:
        positions, clusters = load_aligned_json(jp)
        df = pd.read_csv(csvp)
        items = merge_to_objects(df, positions, clusters)
        outp = jp.with_name(f"{chr_name}_{hours}_{cond_upper}_gene_aligned.json")
        write_output_json(outp, items)
        print(f"[OK] {jp.name} → {outp.name} ({len(items)} genes)")
    except Exception as e:
        print(f"[ERROR] {jp.name}: {e}")
# Out:
# [OK] chr1_12hrs_UNTR_aligned.json → chr1_12hrs_UNTR_gene_aligned.json (1931 genes)
# [OK] chr1_12hrs_VACV_aligned.json → chr1_12hrs_VACV_gene_aligned.json (1931 genes)
# [OK] chr1_18hrs_UNTR_aligned.json → chr1_18hrs_UNTR_gene_aligned.json (1931 genes)
# [OK] chr1_18hrs_VACV_aligned.json → chr1_18hrs_VACV_gene_aligned.json (1931 genes)
# [OK] chr1_24hrs_UNTR_aligned.json → chr1_24hrs_UNTR_gene_aligned.json (1931 genes)
# [OK] chr1_24hrs_VACV_aligned.json → chr1_24hrs_VACV_gene_aligned.json (1931 genes)
# [OK] chr10_12hrs_UNTR_aligned.json → chr10_12hrs_UNTR_gene_aligned.json (1136 genes)
# [OK] chr10_12hrs_VACV_aligned.json → chr10_12hrs_VACV_gene_aligned.json (1136 genes)
# [OK] chr10_18hrs_UNTR_aligned.json → chr10_18hrs_UNTR_gene_aligned.json (1136 genes)
# [OK] chr10_18hrs_VACV_aligned.json → chr10_18hrs_VACV_gene_aligned.json (1136 genes)
# [OK] chr10_24hrs_UNTR_aligned.json → chr10_24hrs_UNTR_gene_aligned.json (1136 genes)
# [OK] chr10_24hrs_VACV_aligned.json → chr10_24hrs_VACV_gene_aligned.json (1136 genes)
# [OK] chr12_12hrs_UNTR_aligned.json → chr12_12hrs_UNTR_gene_aligned.json (1091 genes)
# [OK] chr12_12hrs_VACV_aligned.json → chr12_12hrs_VACV_gene_aligned.json (1091 genes)
# [OK] chr12_18hrs_UNTR_aligned.json → chr12_18hrs_UNTR_gene_aligned.json (1091 genes)
# [OK] chr12_18hrs_VACV_aligned.json → chr12_18hrs_VACV_gene_aligned.json (1091 genes)
# [OK] chr12_24hrs_UNTR_aligned.json → chr12_24hrs_UNTR_gene_aligned.json (1091 genes)
# [OK] chr12_24hrs_VACV_aligned.json → chr12_24hrs_VACV_gene_aligned.json (1091 genes)
# [OK] chr13_12hrs_UNTR_aligned.json → chr13_12hrs_UNTR_gene_aligned.json (854 genes)
# [OK] chr13_12hrs_VACV_aligned.json → chr13_12hrs_VACV_gene_aligned.json (854 genes)
# [OK] chr13_18hrs_UNTR_aligned.json → chr13_18hrs_UNTR_gene_aligned.json (854 genes)
# [OK] chr13_18hrs_VACV_aligned.json → chr13_18hrs_VACV_gene_aligned.json (854 genes)
# [OK] chr13_24hrs_UNTR_aligned.json → chr13_24hrs_UNTR_gene_aligned.json (854 genes)
# [OK] chr13_24hrs_VACV_aligned.json → chr13_24hrs_VACV_gene_aligned.json (854 genes)
# [OK] chr14_12hrs_UNTR_aligned.json → chr14_12hrs_UNTR_gene_aligned.json (1159 genes)
# [OK] chr14_12hrs_VACV_aligned.json → chr14_12hrs_VACV_gene_aligned.json (1159 genes)
# [OK] chr14_18hrs_UNTR_aligned.json → chr14_18hrs_UNTR_gene_aligned.json (1159 genes)
# [OK] chr14_18hrs_VACV_aligned.json → chr14_18hrs_VACV_gene_aligned.json (1159 genes)
# [OK] chr14_24hrs_UNTR_aligned.json → chr14_24hrs_UNTR_gene_aligned.json (1159 genes)
# [OK] chr14_24hrs_VACV_aligned.json → chr14_24hrs_VACV_gene_aligned.json (1159 genes)
# [OK] chr15_12hrs_UNTR_aligned.json → chr15_12hrs_UNTR_gene_aligned.json (691 genes)
# [OK] chr15_12hrs_VACV_aligned.json → chr15_12hrs_VACV_gene_aligned.json (691 genes)
# [OK] chr15_18hrs_UNTR_aligned.json → chr15_18hrs_UNTR_gene_aligned.json (691 genes)
# [OK] chr15_18hrs_VACV_aligned.json → chr15_18hrs_VACV_gene_aligned.json (691 genes)
# [OK] chr15_24hrs_UNTR_aligned.json → chr15_24hrs_UNTR_gene_aligned.json (691 genes)
# [OK] chr15_24hrs_VACV_aligned.json → chr15_24hrs_VACV_gene_aligned.json (691 genes)
# [OK] chr16_12hrs_UNTR_aligned.json → chr16_12hrs_UNTR_gene_aligned.json (1524 genes)
# [OK] chr16_12hrs_VACV_aligned.json → chr16_12hrs_VACV_gene_aligned.json (1524 genes)
# [OK] chr16_18hrs_UNTR_aligned.json → chr16_18hrs_UNTR_gene_aligned.json (1524 genes)
# [OK] chr16_18hrs_VACV_aligned.json → chr16_18hrs_VACV_gene_aligned.json (1524 genes)
# [OK] chr16_24hrs_UNTR_aligned.json → chr16_24hrs_UNTR_gene_aligned.json (1524 genes)
# [OK] chr16_24hrs_VACV_aligned.json → chr16_24hrs_VACV_gene_aligned.json (1524 genes)
# [OK] chr18_12hrs_UNTR_aligned.json → chr18_12hrs_UNTR_gene_aligned.json (550 genes)
# [OK] chr18_12hrs_VACV_aligned.json → chr18_12hrs_VACV_gene_aligned.json (550 genes)
# [OK] chr18_18hrs_UNTR_aligned.json → chr18_18hrs_UNTR_gene_aligned.json (550 genes)
# [OK] chr18_18hrs_VACV_aligned.json → chr18_18hrs_VACV_gene_aligned.json (550 genes)
# [OK] chr18_24hrs_UNTR_aligned.json → chr18_24hrs_UNTR_gene_aligned.json (550 genes)
# [OK] chr18_24hrs_VACV_aligned.json → chr18_24hrs_VACV_gene_aligned.json (550 genes)
# [OK] chr19_12hrs_UNTR_aligned.json → chr19_12hrs_UNTR_gene_aligned.json (622 genes)
# [OK] chr19_12hrs_VACV_aligned.json → chr19_12hrs_VACV_gene_aligned.json (622 genes)
# [OK] chr19_18hrs_UNTR_aligned.json → chr19_18hrs_UNTR_gene_aligned.json (622 genes)
# [OK] chr19_18hrs_VACV_aligned.json → chr19_18hrs_VACV_gene_aligned.json (622 genes)
# [OK] chr19_24hrs_UNTR_aligned.json → chr19_24hrs_UNTR_gene_aligned.json (622 genes)
# [OK] chr19_24hrs_VACV_aligned.json → chr19_24hrs_VACV_gene_aligned.json (622 genes)
# [OK] chr2_12hrs_UNTR_aligned.json → chr2_12hrs_UNTR_gene_aligned.json (1090 genes)
# [OK] chr2_12hrs_VACV_aligned.json → chr2_12hrs_VACV_gene_aligned.json (1090 genes)
# [OK] chr2_18hrs_UNTR_aligned.json → chr2_18hrs_UNTR_gene_aligned.json (1090 genes)
# [OK] chr2_18hrs_VACV_aligned.json → chr2_18hrs_VACV_gene_aligned.json (1090 genes)
# [OK] chr2_24hrs_UNTR_aligned.json → chr2_24hrs_UNTR_gene_aligned.json (1090 genes)
# [OK] chr2_24hrs_VACV_aligned.json → chr2_24hrs_VACV_gene_aligned.json (1090 genes)
# [OK] chr20_12hrs_UNTR_aligned.json → chr20_12hrs_UNTR_gene_aligned.json (1859 genes)
# [OK] chr20_12hrs_VACV_aligned.json → chr20_12hrs_VACV_gene_aligned.json (1859 genes)
# [OK] chr20_18hrs_UNTR_aligned.json → chr20_18hrs_UNTR_gene_aligned.json (1859 genes)
# [OK] chr20_18hrs_VACV_aligned.json → chr20_18hrs_VACV_gene_aligned.json (1859 genes)
# [OK] chr20_24hrs_UNTR_aligned.json → chr20_24hrs_UNTR_gene_aligned.json (1859 genes)
# [OK] chr20_24hrs_VACV_aligned.json → chr20_24hrs_VACV_gene_aligned.json (1859 genes)
# [OK] chr21_12hrs_UNTR_aligned.json → chr21_12hrs_UNTR_gene_aligned.json (1069 genes)
# [OK] chr21_12hrs_VACV_aligned.json → chr21_12hrs_VACV_gene_aligned.json (1069 genes)
# [OK] chr21_18hrs_UNTR_aligned.json → chr21_18hrs_UNTR_gene_aligned.json (1069 genes)
# [OK] chr21_18hrs_VACV_aligned.json → chr21_18hrs_VACV_gene_aligned.json (1069 genes)
# [OK] chr21_24hrs_UNTR_aligned.json → chr21_24hrs_UNTR_gene_aligned.json (1069 genes)
# [OK] chr21_24hrs_VACV_aligned.json → chr21_24hrs_VACV_gene_aligned.json (1069 genes)
# [OK] chr22_12hrs_UNTR_aligned.json → chr22_12hrs_UNTR_gene_aligned.json (1002 genes)
# [OK] chr22_12hrs_VACV_aligned.json → chr22_12hrs_VACV_gene_aligned.json (1002 genes)
# [OK] chr22_18hrs_UNTR_aligned.json → chr22_18hrs_UNTR_gene_aligned.json (1002 genes)
# [OK] chr22_18hrs_VACV_aligned.json → chr22_18hrs_VACV_gene_aligned.json (1002 genes)
# [OK] chr22_24hrs_UNTR_aligned.json → chr22_24hrs_UNTR_gene_aligned.json (1002 genes)
# [OK] chr22_24hrs_VACV_aligned.json → chr22_24hrs_VACV_gene_aligned.json (1002 genes)
# [OK] chr23_12hrs_UNTR_aligned.json → chr23_12hrs_UNTR_gene_aligned.json (733 genes)
# [OK] chr23_12hrs_VACV_aligned.json → chr23_12hrs_VACV_gene_aligned.json (733 genes)
# [OK] chr23_18hrs_UNTR_aligned.json → chr23_18hrs_UNTR_gene_aligned.json (733 genes)
# [OK] chr23_18hrs_VACV_aligned.json → chr23_18hrs_VACV_gene_aligned.json (733 genes)
# [OK] chr23_24hrs_UNTR_aligned.json → chr23_24hrs_UNTR_gene_aligned.json (733 genes)
# [OK] chr23_24hrs_VACV_aligned.json → chr23_24hrs_VACV_gene_aligned.json (733 genes)
# [OK] chr25_12hrs_UNTR_aligned.json → chr25_12hrs_UNTR_gene_aligned.json (824 genes)
# [OK] chr25_12hrs_VACV_aligned.json → chr25_12hrs_VACV_gene_aligned.json (824 genes)
# [OK] chr25_18hrs_UNTR_aligned.json → chr25_18hrs_UNTR_gene_aligned.json (824 genes)
# [OK] chr25_18hrs_VACV_aligned.json → chr25_18hrs_VACV_gene_aligned.json (824 genes)
# [OK] chr25_24hrs_UNTR_aligned.json → chr25_24hrs_UNTR_gene_aligned.json (824 genes)
# [OK] chr25_24hrs_VACV_aligned.json → chr25_24hrs_VACV_gene_aligned.json (824 genes)
# [OK] chr26_12hrs_UNTR_aligned.json → chr26_12hrs_UNTR_gene_aligned.json (683 genes)
# [OK] chr26_12hrs_VACV_aligned.json → chr26_12hrs_VACV_gene_aligned.json (683 genes)
# [OK] chr26_18hrs_UNTR_aligned.json → chr26_18hrs_UNTR_gene_aligned.json (683 genes)
# [OK] chr26_18hrs_VACV_aligned.json → chr26_18hrs_VACV_gene_aligned.json (683 genes)
# [OK] chr26_24hrs_UNTR_aligned.json → chr26_24hrs_UNTR_gene_aligned.json (683 genes)
# [OK] chr26_24hrs_VACV_aligned.json → chr26_24hrs_VACV_gene_aligned.json (683 genes)
# [OK] chr27_12hrs_UNTR_aligned.json → chr27_12hrs_UNTR_gene_aligned.json (328 genes)
# [OK] chr27_12hrs_VACV_aligned.json → chr27_12hrs_VACV_gene_aligned.json (328 genes)
# [OK] chr27_18hrs_UNTR_aligned.json → chr27_18hrs_UNTR_gene_aligned.json (328 genes)
# [OK] chr27_18hrs_VACV_aligned.json → chr27_18hrs_VACV_gene_aligned.json (328 genes)
# [OK] chr27_24hrs_UNTR_aligned.json → chr27_24hrs_UNTR_gene_aligned.json (328 genes)
# [OK] chr27_24hrs_VACV_aligned.json → chr27_24hrs_VACV_gene_aligned.json (328 genes)
# [OK] chr28_12hrs_UNTR_aligned.json → chr28_12hrs_UNTR_gene_aligned.json (328 genes)
# [OK] chr28_12hrs_VACV_aligned.json → chr28_12hrs_VACV_gene_aligned.json (328 genes)
# [OK] chr28_18hrs_UNTR_aligned.json → chr28_18hrs_UNTR_gene_aligned.json (328 genes)
# [OK] chr28_18hrs_VACV_aligned.json → chr28_18hrs_VACV_gene_aligned.json (328 genes)
# [OK] chr28_24hrs_UNTR_aligned.json → chr28_24hrs_UNTR_gene_aligned.json (328 genes)
# [OK] chr28_24hrs_VACV_aligned.json → chr28_24hrs_VACV_gene_aligned.json (328 genes)
# [OK] chr29_12hrs_UNTR_aligned.json → chr29_12hrs_UNTR_gene_aligned.json (370 genes)
# [OK] chr29_12hrs_VACV_aligned.json → chr29_12hrs_VACV_gene_aligned.json (370 genes)
# [OK] chr29_18hrs_UNTR_aligned.json → chr29_18hrs_UNTR_gene_aligned.json (370 genes)
# [OK] chr29_18hrs_VACV_aligned.json → chr29_18hrs_VACV_gene_aligned.json (370 genes)
# [OK] chr29_24hrs_UNTR_aligned.json → chr29_24hrs_UNTR_gene_aligned.json (370 genes)
# [OK] chr29_24hrs_VACV_aligned.json → chr29_24hrs_VACV_gene_aligned.json (370 genes)
# [OK] chr3_12hrs_UNTR_aligned.json → chr3_12hrs_UNTR_gene_aligned.json (605 genes)
# [OK] chr3_12hrs_VACV_aligned.json → chr3_12hrs_VACV_gene_aligned.json (605 genes)
# [OK] chr3_18hrs_UNTR_aligned.json → chr3_18hrs_UNTR_gene_aligned.json (605 genes)
# [OK] chr3_18hrs_VACV_aligned.json → chr3_18hrs_VACV_gene_aligned.json (605 genes)
# [OK] chr3_24hrs_UNTR_aligned.json → chr3_24hrs_UNTR_gene_aligned.json (605 genes)
# [OK] chr3_24hrs_VACV_aligned.json → chr3_24hrs_VACV_gene_aligned.json (605 genes)
# [OK] chr4_12hrs_UNTR_aligned.json → chr4_12hrs_UNTR_gene_aligned.json (573 genes)
# [OK] chr4_12hrs_VACV_aligned.json → chr4_12hrs_VACV_gene_aligned.json (573 genes)
# [OK] chr4_18hrs_UNTR_aligned.json → chr4_18hrs_UNTR_gene_aligned.json (573 genes)
# [OK] chr4_18hrs_VACV_aligned.json → chr4_18hrs_VACV_gene_aligned.json (573 genes)
# [OK] chr4_24hrs_UNTR_aligned.json → chr4_24hrs_UNTR_gene_aligned.json (573 genes)
# [OK] chr4_24hrs_VACV_aligned.json → chr4_24hrs_VACV_gene_aligned.json (573 genes)
# [OK] chr5_12hrs_UNTR_aligned.json → chr5_12hrs_UNTR_gene_aligned.json (1113 genes)
# [OK] chr5_12hrs_VACV_aligned.json → chr5_12hrs_VACV_gene_aligned.json (1113 genes)
# [OK] chr5_18hrs_UNTR_aligned.json → chr5_18hrs_UNTR_gene_aligned.json (1113 genes)
# [OK] chr5_18hrs_VACV_aligned.json → chr5_18hrs_VACV_gene_aligned.json (1113 genes)
# [OK] chr5_24hrs_UNTR_aligned.json → chr5_24hrs_UNTR_gene_aligned.json (1113 genes)
# [OK] chr5_24hrs_VACV_aligned.json → chr5_24hrs_VACV_gene_aligned.json (1113 genes)
# [OK] chr6_12hrs_UNTR_aligned.json → chr6_12hrs_UNTR_gene_aligned.json (1639 genes)
# [OK] chr6_12hrs_VACV_aligned.json → chr6_12hrs_VACV_gene_aligned.json (1639 genes)
# [OK] chr6_18hrs_UNTR_aligned.json → chr6_18hrs_UNTR_gene_aligned.json (1639 genes)
# [OK] chr6_18hrs_VACV_aligned.json → chr6_18hrs_VACV_gene_aligned.json (1639 genes)
# [OK] chr6_24hrs_UNTR_aligned.json → chr6_24hrs_UNTR_gene_aligned.json (1639 genes)
# [OK] chr6_24hrs_VACV_aligned.json → chr6_24hrs_VACV_gene_aligned.json (1639 genes)
# [OK] chr7_12hrs_UNTR_aligned.json → chr7_12hrs_UNTR_gene_aligned.json (843 genes)
# [OK] chr7_12hrs_VACV_aligned.json → chr7_12hrs_VACV_gene_aligned.json (843 genes)
# [OK] chr7_18hrs_UNTR_aligned.json → chr7_18hrs_UNTR_gene_aligned.json (843 genes)
# [OK] chr7_18hrs_VACV_aligned.json → chr7_18hrs_VACV_gene_aligned.json (843 genes)
# [OK] chr7_24hrs_UNTR_aligned.json → chr7_24hrs_UNTR_gene_aligned.json (843 genes)
# [OK] chr7_24hrs_VACV_aligned.json → chr7_24hrs_VACV_gene_aligned.json (843 genes)
