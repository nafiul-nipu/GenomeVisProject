# %%
import pyBigWig

# %%
bw = pyBigWig.open("data/GSE248049/ata-sec/12hr_mock_infected_ATAC_sec_bio_rep_1.bw")

# %%
bw.isBigWig()
# Out:
# True

# %%
bw.chroms()
# Out:
# {'chr1': 126035930,
#  'chr10': 128595539,
#  'chr11': 128539186,
#  'chr12': 108555830,
#  'chr13': 98384682,
#  'chr14': 107702431,
#  'chr15': 91754291,
#  'chr16': 75148670,
#  'chr17': 71996105,
#  'chr18': 72318688,
#  'chr19': 33263144,
#  'chr2': 90373283,
#  'chr20': 130588469,
#  'chr21': 127223203,
#  'chr22': 101219884,
#  'chr23': 82825804,
#  'chr24': 84932903,
#  'chr25': 85787240,
#  'chr26': 58131712,
#  'chr27': 48547382,
#  'chr28': 21531802,
#  'chr29': 24206276,
#  'chr3': 92142175,
#  'chr30': 130038232,
#  'chr31': 6181219,
#  'chr4': 91010382,
#  'chr5': 75399963,
#  'chr6': 50890351,
#  'chr7': 135778131,
#  'chr8': 139301422,
#  'chr9': 125710982}

# %%
bw.header()
# Out:
# {'version': 4,
#  'nLevels': 10,
#  'nBasesCovered': 2733044943,
#  'minVal': 0,
#  'maxVal': 590,
#  'sumData': 183364270,
#  'sumSquared': 950901393}

# %%
bw.values("1", 0, 3)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 bw.values("1", 0, 3)
#
# RuntimeError: Invalid interval bounds!
