# %% [markdown]
# > Optional: This script organizes files into `12hrs`, `18hrs`, and `24hrs` subfolders under each chromosome, based on filenames. Neext it creates two subfolders inside each time points based on the mock and infected naming and put the relevant files there
# > Use only if the dataset includes multiple time points in file names and is not organized

# %%
import os
import shutil

base_path = "data/green_monkey/all_structure_files/"
time_points = ["12hrs", "18hrs", "24hrs"]
conditions = ["untr", "vacv"]

# %%
for chr_folder in os.listdir(base_path):
    chr_folder_path = os.path.join(base_path, chr_folder)
    if not os.path.isdir(chr_folder_path) or not chr_folder.startswith('chr'):
        continue

    # Create time point subfolders
    for tp in time_points:
        tp_folder = os.path.join(chr_folder_path, tp)
        os.makedirs(tp_folder, exist_ok=True)

    # Move files to the correct timepoint subfolder
    for filename in os.listdir(chr_folder_path):
        file_path = os.path.join(chr_folder_path, filename)
        if os.path.isdir(file_path):  # Skip folders
            continue
        for tp in time_points:
            if tp in filename:
                target_path = os.path.join(chr_folder_path, tp, filename)
                shutil.move(file_path, target_path)
                print(f"Moved {filename} → {tp}/")
                break  # Move only once

print("Done.")
# Out:
# Done.

# %%
for chr_folder in os.listdir(base_path):
    chr_folder_path = os.path.join(base_path, chr_folder)
    if not os.path.isdir(chr_folder_path) or not chr_folder.startswith('chr'):
        continue

    for tp in time_points:
        tp_folder = os.path.join(chr_folder_path, tp)
        if not os.path.isdir(tp_folder):
            continue

        # Create condition subfolders
        for cond in conditions:
            cond_folder = os.path.join(tp_folder, cond)
            os.makedirs(cond_folder, exist_ok=True)
            print(f"Created: {cond_folder}")

        # Find and move files based on condition substring
        for fname in os.listdir(tp_folder):
            file_path = os.path.join(tp_folder, fname)
            if not os.path.isfile(file_path):
                continue  # Skip directories

            fname_lower = fname.lower()
            matched = False
            for cond in conditions:
                if cond in fname_lower:
                    target_path = os.path.join(tp_folder, cond, fname)
                    shutil.move(file_path, target_path)
                    print(f"Moved {fname} to {tp}/{cond}/")
                    matched = True
                    break  # Move to only one condition
            if not matched:
                print(f"No condition match for: {fname}")

print("Done.")
# Out:
# Created: data/green_monkey/all_structure_files/chr23/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr23/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr23/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr23/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr23/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr23/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr24/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr24/12hrs/vacv
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr24/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr24/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr24/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr24/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr12/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr12/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr12/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr12/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr12/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr12/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr15/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr15/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr15/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr15/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr15/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr15/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr14/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr14/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr14/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr14/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr14/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr14/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr13/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr13/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr13/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr13/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr13/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr13/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr25/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr25/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr25/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr25/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr25/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr25/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr22/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr22/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr22/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr22/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr22/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr22/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr4/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr4/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr4/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr4/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr4/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr4/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr3/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr3/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr3/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr3/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr3/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr3/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr2/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr2/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr2/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr2/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr2/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr2/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr5/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr5/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr5/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr5/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr5/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr5/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr18/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr18/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr18/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr18/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr18/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr18/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr27/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr27/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr27/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr27/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr27/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr27/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr20/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr20/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr20/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr20/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr20/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr20/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr29/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr29/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr29/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr29/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr29/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr29/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr16/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr16/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr16/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr16/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr16/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr16/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr11/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr11/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Created: data/green_monkey/all_structure_files/chr11/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr11/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr11/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr11/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr10/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr10/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr10/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr10/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr10/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr10/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr28/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr28/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr28/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr28/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr28/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr28/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr17/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr17/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr17/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr17/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr17/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr17/24hrs/vacv
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr21/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr21/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr21/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr21/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr21/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr21/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr19/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr19/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr19/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr19/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr19/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr19/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr26/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr26/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr26/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr26/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr26/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr26/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr7/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr7/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr7/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr7/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr7/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr7/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr9/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr9/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr9/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr9/18hrs/vacv
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr9/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr9/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr8/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr8/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr8/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr8/18hrs/vacv
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr8/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr8/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr6/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr6/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr6/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr6/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr6/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr6/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Created: data/green_monkey/all_structure_files/chr1/12hrs/untr
# Created: data/green_monkey/all_structure_files/chr1/12hrs/vacv
# Moved structure_12hrs_untr_with_id0.csv to 12hrs/untr/
# Moved structure_12hrs_untr.csv to 12hrs/untr/
# Moved structure_12hrs_vacv.csv to 12hrs/vacv/
# Moved structure_12hrs_vacv_with_id0.csv to 12hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr1/18hrs/untr
# Created: data/green_monkey/all_structure_files/chr1/18hrs/vacv
# Moved structure_18hrs_untr.csv to 18hrs/untr/
# Moved structure_18hrs_untr_with_id0.csv to 18hrs/untr/
# Moved structure_18hrs_vacv_with_id0.csv to 18hrs/vacv/
# Moved structure_18hrs_vacv.csv to 18hrs/vacv/
# Created: data/green_monkey/all_structure_files/chr1/24hrs/untr
# Created: data/green_monkey/all_structure_files/chr1/24hrs/vacv
# Moved structure_24hrs_vacv.csv to 24hrs/vacv/
# Moved structure_24hrs_untr_with_id0.csv to 24hrs/untr/
# Moved structure_24hrs_vacv_with_id0.csv to 24hrs/vacv/
# Moved structure_24hrs_untr.csv to 24hrs/untr/
# Done.
