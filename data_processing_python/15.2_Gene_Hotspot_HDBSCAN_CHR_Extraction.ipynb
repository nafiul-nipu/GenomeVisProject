# %%
# === HDBSCAN Hotspots — batch over *_aligned.json
# Updates JSON with cluster labels (0=noise, 1..K) and exports GLB shells.
# IMPORTANT: Clusters & shells are computed on CSV gene centers when available
#            , then labels are mapped back to JSON.
#
# Inputs:
#   data/green_monkey/structure_genes_aligned/<chr>/<chr>_*_aligned.json  (or *_alinged.json)
#   data/green_monkey/all_structure_files/<chr>/<time>/<cond>/structure_<time>_<cond>_gene_info.csv
#
# Outputs:
#   1) Updates each *_aligned.json → {"position":[[x,y,z]...], "clusters":[...]}
#   2) GLBs: data/green_monkey/density_shells_hdbscan/<chr>/<time>_<cond>/<chr>_<time>_<cond>_c{cid}_q{q}.glb
#
# Shell params (MATCH TEST PIPELINE): q=(95,90,80,60), sigma=1.8, grid=96, margin=3.0

import os, re, json, math, traceback
from pathlib import Path
from dataclasses import dataclass
from typing import Optional, Tuple, Dict, List

import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

import hdbscan
from hdbscan.validity import validity_index as dbcv_index
from scipy.ndimage import gaussian_filter
from skimage.measure import marching_cubes
import trimesh

import warnings, logging
warnings.filterwarnings("ignore")
logging.getLogger().setLevel(logging.ERROR)

# ---------- Roots ----------
BASE_DIR        = Path("data/green_monkey/structure_genes_aligned")
ALL_STRUCT_ROOT = Path("data/green_monkey/all_structure_files")     # CSVs live here
SHELLS_ROOT     = Path("data/green_monkey/density_shells_hdbscan")

VALIDCONDS = {"untr", "vacv"}   # extend if needed

# ---------- Config (matches test pipeline) ----------
@dataclass
class HDBSCANConfig:
    # clustering
    scale_coords: bool = True
    min_cluster_size_strategy: str = "auto"             # "auto" | "sqrtN" | "fixed"
    fixed_min_cluster_size: int = 20
    min_cluster_size_grid: Tuple[float, float, int] = (0.6, 2.2, 9)   # √N * [lo..hi]
    min_samples_options: Tuple[Optional[float], ...] = (None, 1, 0.5, 1.0)
    allow_single_cluster: bool = False
    cluster_selection_method: str = "eom"
    metric: str = "euclidean"

    # shells — SAME as test
    make_shells: bool = True
    shell_quantiles: Tuple[float, ...] = (95, 90, 80, 60)
    shell_sigma_vox: float = 1.8
    shell_grid_base: int = 96
    shell_margin: float = 3.0

    # export
    export_format: str = "glb"
    decimate_ratio: Optional[float] = 0.0   # 0 to skip; else 0<r<1 keeps r*faces

# ---------- HDBSCAN utilities ----------
def _candidate_mcs(n: int, cfg: HDBSCANConfig) -> List[int]:
    if cfg.min_cluster_size_strategy == "fixed":
        return [max(5, int(cfg.fixed_min_cluster_size))]
    base = math.sqrt(n)
    lo, hi, steps = cfg.min_cluster_size_grid
    vals = np.unique(np.clip(np.rint(base * np.geomspace(lo, hi, steps)), 5, max(5, n//5)).astype(int))
    return [int(v) for v in vals.tolist()]

def _candidate_min_samples(mcs: int, options: Tuple[Optional[float], ...]) -> List[Optional[int]]:
    out: List[Optional[int]] = []
    for opt in options:
        if opt is None: cand = None
        elif opt >= 2:  cand = int(opt)
        else:           cand = max(1, int(round(mcs * float(opt))))
        if cand not in out: out.append(cand)
    return out

def _score_clustering(labels: np.ndarray, X: np.ndarray, clusterer: hdbscan.HDBSCAN) -> float:
    k = len(set(labels)) - (1 if -1 in labels else 0)
    noise = float(np.mean(labels == -1))
    meanp = float(clusterer.probabilities_[labels != -1].mean()) if np.any(labels != -1) else 0.0
    dbcv = 0.0
    try:
        if k >= 2: dbcv = dbcv_index(X, labels)
    except Exception: pass
    sil = 0.0
    try:
        mask = labels != -1
        if k >= 2 and mask.sum() > k: sil = silhouette_score(X[mask], labels[mask], metric="euclidean")
    except Exception: pass
    return 1.00*dbcv + 0.25*sil + 0.20*(1.0 - noise) + 0.10*meanp

def auto_hdbscan(X: np.ndarray, cfg: HDBSCANConfig):
    Xs = StandardScaler().fit_transform(X) if cfg.scale_coords else X.copy()
    best = None; tried = []
    for mcs in _candidate_mcs(len(X), cfg):
        for ms in _candidate_min_samples(mcs, cfg.min_samples_options):
            model = hdbscan.HDBSCAN(
                min_cluster_size=int(mcs),
                min_samples=None if ms is None else int(ms),
                metric=cfg.metric,
                cluster_selection_method=cfg.cluster_selection_method,
                allow_single_cluster=cfg.allow_single_cluster,
                core_dist_n_jobs=1
            ).fit(Xs)
            labs = model.labels_
            score = _score_clustering(labs, Xs, model)
            tried.append(dict(min_cluster_size=mcs, min_samples=ms, score=score,
                              n_clusters=len(set(labs))-(1 if -1 in labs else 0),
                              noise=float(np.mean(labs==-1))))
            if best is None or score > best["score"]:
                best = dict(model=model, labels=labs, score=score,
                            min_cluster_size=mcs, min_samples=ms)
    diag = pd.DataFrame(tried).sort_values("score", ascending=False).reset_index(drop=True)
    return best["model"], best["labels"], Xs, diag

# ---------- Shell helpers (match test) ----------
def _cluster_shells(P: np.ndarray, cfg: HDBSCANConfig):
    if len(P) < 10: return {}, {}
    mins = P.min(0) - cfg.shell_margin
    maxs = P.max(0) + cfg.shell_margin
    extent = maxs - mins
    scale  = cfg.shell_grid_base / max(float(extent.min()), 1e-6)
    shape  = np.maximum(np.round(extent * scale).astype(int), 8)
    edges  = [np.linspace(mins[i], maxs[i], int(shape[i]) + 1) for i in range(3)]
    spacing = extent / shape
    origin  = mins

    H, _ = np.histogramdd(P, bins=edges)
    dens = gaussian_filter(H.astype(np.float32), sigma=cfg.shell_sigma_vox, mode="constant")
    vals = dens[dens > 0]
    if vals.size == 0: return {}, {}
    levels = {q: float(np.percentile(vals, q)) for q in cfg.shell_quantiles}

    meshes = {}
    for q, lvl in levels.items():
        V, F, _, _ = marching_cubes(dens, level=lvl, spacing=spacing)
        V = V + origin
        meshes[q] = trimesh.Trimesh(vertices=V, faces=F, process=True)
    return meshes, levels

# ---------- JSON + CSV helpers ----------
# Accept BOTH: ..._aligned.json  /  ..._gene_aligned.json  (and typo _alinged)
FNAME_RE = re.compile(
    r"""^
    (?P<chr>chr[0-9XYM]+)
    _(?P<time>\d+hr?s?)
    _(?P<cond>[A-Za-z]+)
    (?:_gene)?_
    (?:aligned|alinged)\.json$
    """, re.VERBOSE | re.IGNORECASE
)

def parse_fname(p: Path) -> Optional[Tuple[str, str, str]]:
    m = FNAME_RE.match(p.name)
    if not m: return None
    return m.group("chr").lower(), m.group("time").lower(), m.group("cond").lower()

def _peer_csv_path(chr_name: str, time_name: str, cond_name: str) -> Path:
    # time_name like "12hrs" or "12hr"
    return (ALL_STRUCT_ROOT / chr_name / time_name / cond_name /
            f"structure_{time_name}_{cond_name}_gene_info.csv")

def _load_gene_csv_points(csv_path: Path) -> Tuple[np.ndarray, List[str]]:
    """Load CSV gene centers and gene_name column."""
    df = pd.read_csv(csv_path)
    pts_df = df[["middle_x", "middle_y", "middle_z"]].dropna()
    if "gene_name" not in df.columns:
        raise ValueError(f"'gene_name' column not found in {csv_path}")
    names = df.loc[pts_df.index, "gene_name"].astype(str).tolist()
    pts = pts_df.values.astype(np.float32)
    if len(pts) < 10:
        raise ValueError(f"Too few CSV gene centers: {len(pts)} in {csv_path}")
    return pts, names

def _load_positions_from_json(jpath: Path) -> Tuple[np.ndarray, Optional[List[str]]]:
    """Robust loader: dict{'position'|'positions','ids'?} | list[[x,y,z]...] | list[{x,y,z}|{middle_x,...}]"""
    with jpath.open("r") as f:
        data = json.load(f)

    ids: Optional[List[str]] = None

    if isinstance(data, dict):
        pts = data.get("positions", data.get("position"))
        if pts is None: raise ValueError(f"No 'positions' or 'position' in {jpath}")
        arr = np.asarray(pts, dtype=float)
        # optional ids parallel to positions
        if "ids" in data:
            ids = [str(x) for x in data["ids"]]
            if len(ids) != len(arr):
                raise ValueError(f"'ids' length != positions length in {jpath}")
    elif isinstance(data, list):
        if not data: raise ValueError(f"Empty list in {jpath}")
        first = data[0]
        if isinstance(first, (list, tuple)) and len(first) == 3:
            arr = np.asarray(data, dtype=float)
        elif isinstance(first, dict):
            if all(k in first for k in ("x","y","z")):
                arr = np.asarray([[d["x"], d["y"], d["z"]] for d in data], dtype=float)
            elif all(k in first for k in ("middle_x","middle_y","middle_z")):
                arr = np.asarray([[d["middle_x"], d["middle_y"], d["middle_z"]] for d in data], dtype=float)
            else:
                raise ValueError(f"List of dicts in {jpath} missing (x,y,z) or (middle_x, middle_y, middle_z)")
        else:
            raise ValueError(f"Unsupported list element type {type(first)} in {jpath}")
    else:
        raise ValueError(f"Unsupported JSON root type {type(data)} in {jpath}")

    if arr.ndim != 2 or arr.shape[1] != 3:
        raise ValueError(f"Expected Nx3 positions in {jpath}, got {arr.shape}")
    return arr.astype(np.float32), ids

def _write_clusters_back_json(jpath: Path, positions: np.ndarray, labels: np.ndarray):
    remapped = np.where(labels == -1, 0, labels + 1)  # 0=noise, 1..K
    with jpath.open("r") as f:
        data = json.load(f)
    data["position"] = np.asarray(positions, dtype=float).tolist()
    if "positions" in data:
        try: del data["positions"]
        except Exception: pass
    data["clusters"] = remapped.astype(int).tolist()
    tmp = jpath.with_suffix(".json.tmp")
    with tmp.open("w") as f:
        json.dump(data, f, separators=(",", ":"), ensure_ascii=False, indent=2)
    tmp.replace(jpath)

# ---------- Per-file run ----------
def process_aligned_json(jpath: Path, cfg: HDBSCANConfig):
    parsed = parse_fname(jpath)
    if not parsed:
        raise ValueError(f"Unrecognized filename pattern: {jpath.name}")
    chr_name, time_name, cond_name = parsed
    if cond_name not in VALIDCONDS:
        raise ValueError(f"Unknown condition '{cond_name}' in {jpath.name} (allowed: {sorted(VALIDCONDS)})")

    # Load JSON beads (+ ids) and CSV gene centers (+ names)
    json_pts, json_ids = _load_positions_from_json(jpath)
    csv_path = _peer_csv_path(chr_name, time_name, cond_name)
    if not csv_path.exists():
        raise FileNotFoundError(f"Peer CSV not found for {jpath.name}: {csv_path}")

    csv_pts, csv_names = _load_gene_csv_points(csv_path)
    print(f"[DATA] {jpath.name}: JSON N={len(json_pts)}  CSV N={len(csv_pts)}  (clustering on CSV; mapping by gene_name)")

    if json_ids is None:
        raise ValueError(
            f"{jpath.name} missing 'ids'. "
            f"This pipeline requires JSON 'ids' to match CSV 'gene_name' for label mapping."
        )

    # Cluster on CSV gene centers (matches test)
    model, base_labels, _, _ = auto_hdbscan(csv_pts, cfg)

    # Map labels to JSON by gene_name (NO nearest-neighbor)
    # Build name -> label dict (case-sensitive by default)
    name_to_label: Dict[str, int] = {str(n): int(l) for n, l in zip(csv_names, base_labels)}
    # If case-insensitive mapping is needed, uncomment the next line and the .lower() usage below:
    # name_to_label = {str(n).lower(): int(l) for n, l in zip(csv_names, base_labels)}

    json_labels = np.array([name_to_label.get(str(g)) for g in json_ids], dtype=object)
    # Any missing names → mark as noise (-1)
    missing_mask = pd.isna(json_labels)
    if missing_mask.any():
        nmiss = int(missing_mask.sum())
        print(f"[WARN] {jpath.name}: {nmiss} / {len(json_labels)} ids not found in CSV gene_name — set to noise.")
        json_labels[missing_mask] = -1
    json_labels = json_labels.astype(int)

    # Write clusters to JSON
    _write_clusters_back_json(jpath, json_pts, json_labels)

    # Export GLB shells from the same base set we clustered (matches test visuals)
    if cfg.make_shells:
        uniq = sorted([u for u in np.unique(base_labels) if u != -1])
        out_dir = SHELLS_ROOT / chr_name / f"{time_name}_{cond_name}"
        out_dir.mkdir(parents=True, exist_ok=True)
        for cid in uniq:
            P = csv_pts[base_labels == cid]
            meshes, levels = _cluster_shells(P, cfg)
            for q, mesh in meshes.items():
                # optional decimation
                if cfg.decimate_ratio and cfg.decimate_ratio > 0.0:
                    try:
                        target = int(len(mesh.faces) * float(cfg.decimate_ratio))
                        if 50 < target < len(mesh.faces):
                            mesh = mesh.simplify_quadratic_decimation(target)
                    except Exception:
                        pass
                suffix = cfg.export_format.lower().strip(".")
                opath = out_dir / f"{chr_name}_{time_name}_{cond_name}_c{cid}_q{int(q)}.{suffix}"
                mesh.export(opath)
                try:
                    bmin, bmax = mesh.bounds
                    print(f"[SHELL] {opath.name} V={len(mesh.vertices)} F={len(mesh.faces)} "
                          f"bbox=({np.round(bmin,2)}→{np.round(bmax,2)}) level={levels[q]:.4f}")
                except Exception:
                    print(f"[SHELL] {opath.name} V={len(mesh.vertices)} F={len(mesh.faces)}")

    n_clusters = int(len(set(base_labels)) - (1 if -1 in base_labels else 0))
    noise_frac = float(np.mean(base_labels == -1))
    return dict(chr=chr_name, time=time_name, cond=cond_name,
                n_points=int(len(csv_pts)), n_clusters=n_clusters,
                noise_frac=noise_frac,
                mcs=int(model.min_cluster_size),
                ms=None if model.min_samples is None else int(model.min_samples))

# ---------- Driver ----------
def main():
    SHELLS_ROOT.mkdir(parents=True, exist_ok=True)
    cfg = HDBSCANConfig()  # uses the test settings
    print(f"[CFG] shells q={cfg.shell_quantiles} sigma={cfg.shell_sigma_vox} grid={cfg.shell_grid_base}")

    chrom_dirs = [d for d in BASE_DIR.iterdir() if d.is_dir()]
    done = skipped = failed = 0

    for chrom_dir in sorted(chrom_dirs, key=lambda p: p.name):
        chr_name = chrom_dir.name
        print(f"\n=== {chr_name} ===")

        # pick up aligned + typo, with or without _gene
        jsons = sorted({
            *chrom_dir.glob(f"{chr_name}_*_aligned.json"),
            *chrom_dir.glob(f"{chr_name}_*_alinged.json"),
            *chrom_dir.glob(f"{chr_name}_*_gene_aligned.json"),
            *chrom_dir.glob(f"{chr_name}_*_gene_alinged.json"),
        }, key=lambda p: p.name)

        if not jsons:
            print(f"[SKIP] No *_aligned.json in {chrom_dir}")
            skipped += 1
            continue

        ok = 0
        for jp in jsons:
            try:
                info = process_aligned_json(jp, cfg)
                print(f"[OK] {jp.name}: pts={info['n_points']} "
                      f"clusters={info['n_clusters']} noise={info['noise_frac']:.2f} "
                      f"mcs={info['mcs']} ms={info['ms']}")
                ok += 1
            except Exception as e:
                print(f"[FAIL] {jp.name}: {e}")
                traceback.print_exc()
                failed += 1

        done += (1 if ok > 0 else 0)

    print("\n=== Summary ===")
    print(f"Completed chromosomes: {done}")
    print(f"Skipped chromosomes:   {skipped}")
    print(f"Failures:              {failed}")

if __name__ == "__main__":
    main()
# Out:
# [CFG] shells q=(95, 90, 80, 60) sigma=1.8 grid=96
#
# === chr1 ===
# [DATA] chr1_12hrs_untr_aligned.json: JSON N=1931  CSV N=1931  (clustering on CSV; mapping by gene_name)
# [SHELL] chr1_12hrs_untr_c0_q95.glb V=6280 F=12508 bbox=([-43.03  38.23 -54.54]→[-36.87  43.83 -49.96]) level=0.0485
# [SHELL] chr1_12hrs_untr_c0_q90.glb V=9324 F=18648 bbox=([-43.11  38.13 -54.76]→[-36.79  43.93 -49.85]) level=0.0323
# [SHELL] chr1_12hrs_untr_c0_q80.glb V=12475 F=24962 bbox=([-43.24  37.92 -54.97]→[-36.68  44.06 -48.76]) level=0.0145
# [SHELL] chr1_12hrs_untr_c0_q60.glb V=13888 F=27764 bbox=([-43.54  37.4  -55.23]→[-36.48  44.29 -48.32]) level=0.0019
# [SHELL] chr1_12hrs_untr_c1_q95.glb V=6120 F=12172 bbox=([-41.18  39.87 -50.69]→[-37.65  44.86 -46.91]) level=0.0240
# [SHELL] chr1_12hrs_untr_c1_q90.glb V=9627 F=19258 bbox=([-41.24  39.82 -50.75]→[-37.56  44.93 -46.7 ]) level=0.0159
# [SHELL] chr1_12hrs_untr_c1_q80.glb V=13169 F=26362 bbox=([-41.33  39.74 -50.83]→[-37.45  45.02 -46.5 ]) level=0.0075
# [SHELL] chr1_12hrs_untr_c1_q60.glb V=15105 F=30222 bbox=([-41.49  39.59 -50.99]→[-37.28  45.19 -46.3 ]) level=0.0011
# [OK] chr1_12hrs_untr_aligned.json: pts=1931 clusters=2 noise=0.26 mcs=26 ms=None
# [DATA] chr1_12hrs_vacv_aligned.json: JSON N=1931  CSV N=1931  (clustering on CSV; mapping by gene_name)
# [SHELL] chr1_12hrs_vacv_c0_q95.glb V=6290 F=12524 bbox=([-48.58  12.56 -67.57]→[-42.49  15.99 -63.13]) level=0.0323
# [SHELL] chr1_12hrs_vacv_c0_q90.glb V=9917 F=19828 bbox=([-48.77  12.38 -67.67]→[-42.42  16.53 -63.07]) level=0.0208
# [SHELL] chr1_12hrs_vacv_c0_q80.glb V=13828 F=27662 bbox=([-48.95  12.23 -67.79]→[-42.33  16.75 -62.99]) level=0.0098
# [SHELL] chr1_12hrs_vacv_c0_q60.glb V=15015 F=30038 bbox=([-49.16  12.01 -67.98]→[-42.17  17.06 -62.85]) level=0.0015
# [SHELL] chr1_12hrs_vacv_c1_q95.glb V=6866 F=13660 bbox=([-48.54  15.04 -72.58]→[-43.71  19.78 -65.36]) level=0.0263
# [SHELL] chr1_12hrs_vacv_c1_q90.glb V=10818 F=21600 bbox=([-48.7   14.97 -72.69]→[-43.36  19.86 -65.26]) level=0.0155
# [SHELL] chr1_12hrs_vacv_c1_q80.glb V=16214 F=32436 bbox=([-48.86  14.88 -72.87]→[-43.04  19.96 -65.11]) level=0.0063
# [SHELL] chr1_12hrs_vacv_c1_q60.glb V=19035 F=38094 bbox=([-49.07  14.7  -73.12]→[-42.79  20.14 -64.9 ]) level=0.0008
# [OK] chr1_12hrs_vacv_aligned.json: pts=1931 clusters=2 noise=0.35 mcs=82 ms=41
# [DATA] chr1_18hrs_untr_aligned.json: JSON N=1931  CSV N=1931  (clustering on CSV; mapping by gene_name)
# [SHELL] chr1_18hrs_untr_c0_q95.glb V=7312 F=14572 bbox=([ 48.1   20.19 -89.88]→[ 53.49  24.07 -85.32]) level=0.0321
# [SHELL] chr1_18hrs_untr_c0_q90.glb V=10748 F=21488 bbox=([ 47.73  20.14 -90.04]→[ 53.61  24.16 -85.23]) level=0.0213
# [SHELL] chr1_18hrs_untr_c0_q80.glb V=14942 F=29904 bbox=([ 47.56  20.06 -90.21]→[ 53.77  24.28 -85.13]) level=0.0104
# [SHELL] chr1_18hrs_untr_c0_q60.glb V=15689 F=31398 bbox=([ 47.37  19.85 -90.43]→[ 54.01  24.47 -84.86]) level=0.0016
# [SHELL] chr1_18hrs_untr_c1_q95.glb V=3900 F=7780 bbox=([ 50.97  18.69 -92.76]→[ 54.38  20.97 -86.8 ]) level=0.0160
# [SHELL] chr1_18hrs_untr_c1_q90.glb V=6290 F=12528 bbox=([ 50.83  18.52 -93.33]→[ 54.74  21.03 -86.69]) level=0.0083
# [SHELL] chr1_18hrs_untr_c1_q80.glb V=9452 F=18888 bbox=([ 50.7   18.39 -93.49]→[ 54.89  21.12 -86.56]) level=0.0025
# [SHELL] chr1_18hrs_untr_c1_q60.glb V=13224 F=26444 bbox=([ 50.53  18.21 -93.67]→[ 55.07  21.28 -86.39]) level=0.0002
# [SHELL] chr1_18hrs_untr_c2_q95.glb V=3892 F=7756 bbox=([ 52.61  19.7  -93.  ]→[ 56.58  23.83 -89.9 ]) level=0.0215
# [SHELL] chr1_18hrs_untr_c2_q90.glb V=6186 F=12364 bbox=([ 52.56  19.6  -93.07]→[ 56.68  23.92 -89.82]) level=0.0129
# [SHELL] chr1_18hrs_untr_c2_q80.glb V=8916 F=17852 bbox=([ 52.49  19.51 -93.16]→[ 56.79  24.02 -89.73]) level=0.0055
# [SHELL] chr1_18hrs_untr_c2_q60.glb V=10016 F=20028 bbox=([ 52.34  19.33 -93.31]→[ 56.96  24.19 -89.56]) level=0.0006
# [OK] chr1_18hrs_untr_aligned.json: pts=1931 clusters=3 noise=0.39 mcs=59 ms=30
# [DATA] chr1_18hrs_vacv_aligned.json: JSON N=1931  CSV N=1931  (clustering on CSV; mapping by gene_name)
# [SHELL] chr1_18hrs_vacv_c0_q95.glb V=8838 F=17604 bbox=([19.98  6.53 62.33]→[25.11 11.79 69.76]) level=0.0339
# [SHELL] chr1_18hrs_vacv_c0_q90.glb V=14198 F=28344 bbox=([19.84  6.28 62.24]→[25.25 11.95 70.55]) level=0.0219
# [SHELL] chr1_18hrs_vacv_c0_q80.glb V=20884 F=41816 bbox=([19.71  6.03 62.15]→[25.54 12.11 70.81]) level=0.0109
# [SHELL] chr1_18hrs_vacv_c0_q60.glb V=21836 F=43708 bbox=([19.51  5.64 61.97]→[25.8  12.35 71.02]) level=0.0021
# [SHELL] chr1_18hrs_vacv_c1_q95.glb V=8892 F=17668 bbox=([22.78  5.18 66.12]→[28.19 10.12 74.18]) level=0.0258
# [SHELL] chr1_18hrs_vacv_c1_q90.glb V=15212 F=30360 bbox=([22.64  5.06 65.98]→[28.42 10.44 74.38]) level=0.0165
# [SHELL] chr1_18hrs_vacv_c1_q80.glb V=22380 F=44800 bbox=([22.43  4.94 65.84]→[29.03 10.63 74.57]) level=0.0080
# [SHELL] chr1_18hrs_vacv_c1_q60.glb V=23964 F=47976 bbox=([22.18  4.75 65.64]→[29.29 10.86 74.79]) level=0.0015
# [OK] chr1_18hrs_vacv_aligned.json: pts=1931 clusters=2 noise=0.05 mcs=26 ms=13
# [DATA] chr1_24hrs_untr_aligned.json: JSON N=1931  CSV N=1931  (clustering on CSV; mapping by gene_name)
# [SHELL] chr1_24hrs_untr_c0_q95.glb V=4350 F=8656 bbox=([ 18.45  21.91 -68.92]→[ 21.82  26.07 -65.  ]) level=0.0258
# [SHELL] chr1_24hrs_untr_c0_q90.glb V=6594 F=13176 bbox=([ 18.4   21.72 -69.05]→[ 21.88  26.21 -64.94]) level=0.0169
# [SHELL] chr1_24hrs_untr_c0_q80.glb V=9178 F=18364 bbox=([ 18.24  21.55 -69.18]→[ 21.97  26.44 -64.85]) level=0.0073
# [SHELL] chr1_24hrs_untr_c0_q60.glb V=10754 F=21504 bbox=([ 18.03  21.31 -69.38]→[ 22.15  26.7  -64.64]) level=0.0008
# [SHELL] chr1_24hrs_untr_c1_q95.glb V=1998 F=3972 bbox=([ 18.85  22.33 -71.03]→[ 20.3   25.91 -69.83]) level=0.0177
# [SHELL] chr1_24hrs_untr_c1_q90.glb V=3164 F=6320 bbox=([ 18.78  22.27 -71.11]→[ 20.36  25.97 -69.73]) level=0.0099
# [SHELL] chr1_24hrs_untr_c1_q80.glb V=4420 F=8836 bbox=([ 18.69  22.19 -71.24]→[ 20.45  26.06 -69.62]) level=0.0030
# [SHELL] chr1_24hrs_untr_c1_q60.glb V=6200 F=12400 bbox=([ 18.55  22.05 -71.4 ]→[ 20.6   26.2  -69.47]) level=0.0002
# [SHELL] chr1_24hrs_untr_c2_q95.glb V=5751 F=11468 bbox=([ 20.18  24.75 -72.3 ]→[ 23.62  27.98 -67.84]) level=0.0332
# [SHELL] chr1_24hrs_untr_c2_q90.glb V=8576 F=17168 bbox=([ 20.11  24.68 -72.39]→[ 23.69  28.05 -67.77]) level=0.0224
# [SHELL] chr1_24hrs_untr_c2_q80.glb V=10788 F=21572 bbox=([ 19.97  24.59 -72.61]→[ 23.8   28.15 -67.68]) level=0.0106
# [SHELL] chr1_24hrs_untr_c2_q60.glb V=12558 F=25124 bbox=([ 19.73  24.41 -72.83]→[ 24.    28.33 -67.46]) level=0.0013
# [OK] chr1_24hrs_untr_aligned.json: pts=1931 clusters=3 noise=0.46 mcs=59 ms=30
# [DATA] chr1_24hrs_vacv_aligned.json: JSON N=1931  CSV N=1931  (clustering on CSV; mapping by gene_name)
# [SHELL] chr1_24hrs_vacv_c0_q95.glb V=5954 F=11872 bbox=([ 18.18  91.88 -14.87]→[ 22.04  96.33 -10.3 ]) level=0.0330
# [SHELL] chr1_24hrs_vacv_c0_q90.glb V=8726 F=17440 bbox=([ 18.12  91.66 -14.94]→[ 22.19  96.42 -10.19]) level=0.0211
# [SHELL] chr1_24hrs_vacv_c0_q80.glb V=12749 F=25492 bbox=([ 18.03  91.39 -15.03]→[22.33 96.55 -9.72]) level=0.0090
# [SHELL] chr1_24hrs_vacv_c0_q60.glb V=15292 F=30588 bbox=([ 17.87  91.15 -15.19]→[22.52 96.75 -9.46]) level=0.0013
# [SHELL] chr1_24hrs_vacv_c1_q95.glb V=4562 F=9048 bbox=([ 18.7   93.57 -11.02]→[22.55 97.88 -6.  ]) level=0.0240
# [SHELL] chr1_24hrs_vacv_c1_q90.glb V=7334 F=14640 bbox=([ 18.56  93.48 -11.1 ]→[22.72 98.   -5.87]) level=0.0150
# [SHELL] chr1_24hrs_vacv_c1_q80.glb V=10156 F=20332 bbox=([ 18.39  93.37 -11.2 ]→[22.92 98.13 -5.75]) level=0.0065
# [SHELL] chr1_24hrs_vacv_c1_q60.glb V=11606 F=23216 bbox=([ 18.16  93.18 -11.4 ]→[23.16 98.34 -5.52]) level=0.0007
# [OK] chr1_24hrs_vacv_aligned.json: pts=1931 clusters=2 noise=0.49 mcs=82 ms=None
#
# === chr10 ===
# [DATA] chr10_12hrs_untr_aligned.json: JSON N=1136  CSV N=1136  (clustering on CSV; mapping by gene_name)
# [SHELL] chr10_12hrs_untr_c0_q95.glb V=3696 F=7348 bbox=([ -5.89  50.99 -11.33]→[-2.53 54.19 -8.05]) level=0.0114
# [SHELL] chr10_12hrs_untr_c0_q90.glb V=5784 F=11540 bbox=([ -5.98  50.91 -11.39]→[-2.46 54.25 -7.97]) level=0.0069
# [SHELL] chr10_12hrs_untr_c0_q80.glb V=8094 F=16188 bbox=([ -6.09  50.79 -11.46]→[-2.36 54.33 -7.88]) level=0.0027
# [SHELL] chr10_12hrs_untr_c0_q60.glb V=9100 F=18208 bbox=([ -6.26  50.62 -11.61]→[-2.21 54.48 -7.72]) level=0.0003
# [SHELL] chr10_12hrs_untr_c1_q95.glb V=8046 F=16040 bbox=([ -7.77  45.77 -17.37]→[ -0.47  54.22 -11.39]) level=0.0360
# [SHELL] chr10_12hrs_untr_c1_q90.glb V=12029 F=24038 bbox=([ -7.88  45.66 -17.46]→[  0.16  54.38 -11.26]) level=0.0253
# [SHELL] chr10_12hrs_untr_c1_q80.glb V=16361 F=32786 bbox=([ -8.01  45.51 -17.68]→[  0.39  54.96 -10.49]) level=0.0133
# [SHELL] chr10_12hrs_untr_c1_q60.glb V=16140 F=32268 bbox=([ -8.26  45.27 -18.03]→[ 0.66 55.29 -9.73]) level=0.0021
# [OK] chr10_12hrs_untr_aligned.json: pts=1136 clusters=2 noise=0.06 mcs=20 ms=10
# [DATA] chr10_12hrs_vacv_aligned.json: JSON N=1136  CSV N=1136  (clustering on CSV; mapping by gene_name)
# [SHELL] chr10_12hrs_vacv_c0_q95.glb V=4524 F=8940 bbox=([ 43.02  -3.44 -14.43]→[ 46.57  -0.67 -10.84]) level=0.0100
# [SHELL] chr10_12hrs_vacv_c0_q90.glb V=7161 F=14298 bbox=([ 42.95  -3.56 -14.49]→[ 46.63  -0.59 -10.8 ]) level=0.0062
# [SHELL] chr10_12hrs_vacv_c0_q80.glb V=10048 F=20108 bbox=([ 42.86  -3.66 -14.57]→[ 46.72  -0.49 -10.73]) level=0.0026
# [SHELL] chr10_12hrs_vacv_c0_q60.glb V=10848 F=21696 bbox=([ 42.7   -3.83 -14.71]→[ 46.86  -0.34 -10.59]) level=0.0003
# [SHELL] chr10_12hrs_vacv_c1_q95.glb V=10040 F=19972 bbox=([ 34.35  -6.26 -19.81]→[ 42.97   2.36 -13.27]) level=0.0286
# [SHELL] chr10_12hrs_vacv_c1_q90.glb V=15918 F=31796 bbox=([ 34.27  -6.55 -19.88]→[ 43.36   2.46 -13.14]) level=0.0195
# [SHELL] chr10_12hrs_vacv_c1_q80.glb V=22648 F=45332 bbox=([ 34.17  -7.03 -19.98]→[ 44.16   2.58 -13.  ]) level=0.0101
# [SHELL] chr10_12hrs_vacv_c1_q60.glb V=22763 F=45518 bbox=([ 33.97  -7.31 -20.16]→[ 44.48   2.77 -12.78]) level=0.0020
# [OK] chr10_12hrs_vacv_aligned.json: pts=1136 clusters=2 noise=0.05 mcs=20 ms=10
# [DATA] chr10_18hrs_untr_aligned.json: JSON N=1136  CSV N=1136  (clustering on CSV; mapping by gene_name)
# [SHELL] chr10_18hrs_untr_c0_q95.glb V=4316 F=8532 bbox=([-39.96 -23.15 -30.48]→[-36.53 -19.4  -26.48]) level=0.0104
# [SHELL] chr10_18hrs_untr_c0_q90.glb V=6804 F=13564 bbox=([-40.03 -23.21 -30.53]→[-36.46 -19.31 -26.38]) level=0.0063
# [SHELL] chr10_18hrs_untr_c0_q80.glb V=9664 F=19332 bbox=([-40.12 -23.3  -30.62]→[-36.37 -19.2  -26.27]) level=0.0026
# [SHELL] chr10_18hrs_untr_c0_q60.glb V=11160 F=22328 bbox=([-40.27 -23.46 -30.79]→[-36.22 -19.03 -26.1 ]) level=0.0003
# [SHELL] chr10_18hrs_untr_c1_q95.glb V=11364 F=22588 bbox=([-38.19 -20.05 -28.84]→[-33.12 -12.7  -19.24]) level=0.0241
# [SHELL] chr10_18hrs_untr_c1_q90.glb V=18873 F=37718 bbox=([-38.45 -20.16 -29.  ]→[-33.02 -12.61 -19.17]) level=0.0160
# [SHELL] chr10_18hrs_untr_c1_q80.glb V=28000 F=56024 bbox=([-39.2  -21.05 -29.35]→[-32.91 -12.5  -19.07]) level=0.0082
# [SHELL] chr10_18hrs_untr_c1_q60.glb V=29596 F=59252 bbox=([-39.47 -21.31 -29.61]→[-32.73 -12.33 -18.8 ]) level=0.0017
# [OK] chr10_18hrs_untr_aligned.json: pts=1136 clusters=2 noise=0.04 mcs=20 ms=10
# [DATA] chr10_18hrs_vacv_aligned.json: JSON N=1136  CSV N=1136  (clustering on CSV; mapping by gene_name)
# [SHELL] chr10_18hrs_vacv_c0_q95.glb V=13017 F=25846 bbox=([-23.45 -53.25  38.83]→[-17.94 -44.01  49.4 ]) level=0.0228
# [SHELL] chr10_18hrs_vacv_c0_q90.glb V=21413 F=42768 bbox=([-23.5  -53.88  38.7 ]→[-17.84 -43.92  49.52]) level=0.0152
# [SHELL] chr10_18hrs_vacv_c0_q80.glb V=31355 F=62794 bbox=([-23.65 -54.04  38.58]→[-17.62 -43.8   49.97]) level=0.0079
# [SHELL] chr10_18hrs_vacv_c0_q60.glb V=32544 F=65158 bbox=([-23.9  -54.25  38.4 ]→[-17.36 -43.57  50.22]) level=0.0017
# [SHELL] chr10_18hrs_vacv_c1_q95.glb V=4260 F=8436 bbox=([-24.87 -51.98  48.22]→[-20.98 -48.64  52.05]) level=0.0104
# [SHELL] chr10_18hrs_vacv_c1_q90.glb V=6628 F=13216 bbox=([-24.92 -52.13  48.07]→[-20.91 -48.59  52.11]) level=0.0063
# [SHELL] chr10_18hrs_vacv_c1_q80.glb V=9496 F=18988 bbox=([-25.   -52.25  47.95]→[-20.82 -48.51  52.21]) level=0.0024
# [SHELL] chr10_18hrs_vacv_c1_q60.glb V=10910 F=21836 bbox=([-25.14 -52.42  47.78]→[-20.68 -48.34  52.35]) level=0.0003
# [OK] chr10_18hrs_vacv_aligned.json: pts=1136 clusters=2 noise=0.03 mcs=39 ms=20
# [DATA] chr10_24hrs_untr_aligned.json: JSON N=1136  CSV N=1136  (clustering on CSV; mapping by gene_name)
# [SHELL] chr10_24hrs_untr_c0_q95.glb V=3834 F=7616 bbox=([ 30.39 -38.82  21.38]→[ 33.38 -35.48  24.43]) level=0.0111
# [SHELL] chr10_24hrs_untr_c0_q90.glb V=6094 F=12160 bbox=([ 30.22 -38.89  21.32]→[ 33.45 -35.44  24.56]) level=0.0070
# [SHELL] chr10_24hrs_untr_c0_q80.glb V=8347 F=16706 bbox=([ 30.1  -38.99  21.23]→[ 33.54 -35.36  24.67]) level=0.0029
# [SHELL] chr10_24hrs_untr_c0_q60.glb V=9816 F=19644 bbox=([ 29.93 -39.14  21.08]→[ 33.68 -35.22  24.84]) level=0.0004
# [SHELL] chr10_24hrs_untr_c1_q95.glb V=9267 F=18474 bbox=([ 32.59 -37.97  15.75]→[ 38.86 -30.97  22.22]) level=0.0319
# [SHELL] chr10_24hrs_untr_c1_q90.glb V=14400 F=28784 bbox=([ 32.49 -38.59  15.64]→[ 38.97 -30.77  22.42]) level=0.0218
# [SHELL] chr10_24hrs_untr_c1_q80.glb V=19936 F=39884 bbox=([ 32.38 -38.98  15.5 ]→[ 39.19 -30.6   22.98]) level=0.0115
# [SHELL] chr10_24hrs_untr_c1_q60.glb V=20986 F=42000 bbox=([ 32.18 -39.53  15.26]→[ 39.45 -30.36  23.23]) level=0.0023
# [OK] chr10_24hrs_untr_aligned.json: pts=1136 clusters=2 noise=0.04 mcs=39 ms=20
# [DATA] chr10_24hrs_vacv_aligned.json: JSON N=1136  CSV N=1136  (clustering on CSV; mapping by gene_name)
# [SHELL] chr10_24hrs_vacv_c0_q95.glb V=3492 F=6924 bbox=([ 73.51 -64.36  50.7 ]→[ 76.86 -61.59  53.72]) level=0.0097
# [SHELL] chr10_24hrs_vacv_c0_q90.glb V=5500 F=10972 bbox=([ 73.39 -64.46  50.59]→[ 76.95 -61.52  53.81]) level=0.0056
# [SHELL] chr10_24hrs_vacv_c0_q80.glb V=7635 F=15282 bbox=([ 73.29 -64.57  50.48]→[ 77.06 -61.42  53.91]) level=0.0021
# [SHELL] chr10_24hrs_vacv_c0_q60.glb V=8998 F=18004 bbox=([ 73.12 -64.73  50.32]→[ 77.22 -61.25  54.07]) level=0.0002
# [SHELL] chr10_24hrs_vacv_c1_q95.glb V=11828 F=23524 bbox=([ 63.76 -64.93  47.56]→[ 76.22 -60.58  51.68]) level=0.0252
# [SHELL] chr10_24hrs_vacv_c1_q90.glb V=18992 F=37928 bbox=([ 63.67 -65.19  47.26]→[ 76.32 -60.23  51.91]) level=0.0169
# [SHELL] chr10_24hrs_vacv_c1_q80.glb V=27512 F=55084 bbox=([ 63.54 -65.36  47.12]→[ 76.43 -60.05  52.27]) level=0.0086
# [SHELL] chr10_24hrs_vacv_c1_q60.glb V=29267 F=58558 bbox=([ 63.3  -65.55  46.88]→[ 76.64 -59.84  52.53]) level=0.0017
# [OK] chr10_24hrs_vacv_aligned.json: pts=1136 clusters=2 noise=0.04 mcs=39 ms=20
#
# === chr12 ===
# [DATA] chr12_12hrs_untr_aligned.json: JSON N=1091  CSV N=1091  (clustering on CSV; mapping by gene_name)
# [SHELL] chr12_12hrs_untr_c0_q95.glb V=5356 F=10660 bbox=([-19.16 -85.66   0.36]→[-15.58 -81.37   3.33]) level=0.0204
# [SHELL] chr12_12hrs_untr_c0_q90.glb V=7997 F=15988 bbox=([-19.28 -85.73   0.26]→[-15.51 -81.15   3.4 ]) level=0.0127
# [SHELL] chr12_12hrs_untr_c0_q80.glb V=11892 F=23804 bbox=([-1.948e+01 -8.582e+01  8.000e-02]→[-15.41 -80.96   3.48]) level=0.0056
# [SHELL] chr12_12hrs_untr_c0_q60.glb V=13388 F=26788 bbox=([-19.67 -85.97  -0.1 ]→[-15.25 -80.77   3.61]) level=0.0008
# [SHELL] chr12_12hrs_untr_c1_q95.glb V=10878 F=21640 bbox=([-19.51 -83.91   3.29]→[-12.86 -75.11   7.01]) level=0.0187
# [SHELL] chr12_12hrs_untr_c1_q90.glb V=17163 F=34274 bbox=([-19.59 -83.99   3.23]→[-12.78 -75.03   7.35]) level=0.0124
# [SHELL] chr12_12hrs_untr_c1_q80.glb V=24115 F=48294 bbox=([-19.67 -84.1    3.15]→[-12.67 -74.91   7.49]) level=0.0063
# [SHELL] chr12_12hrs_untr_c1_q60.glb V=25361 F=50734 bbox=([-19.86 -84.28   3.  ]→[-12.51 -74.7    7.68]) level=0.0010
# [OK] chr12_12hrs_untr_aligned.json: pts=1091 clusters=2 noise=0.14 mcs=20 ms=10
# [DATA] chr12_12hrs_vacv_aligned.json: JSON N=1091  CSV N=1091  (clustering on CSV; mapping by gene_name)
# [SHELL] chr12_12hrs_vacv_c0_q95.glb V=5569 F=11090 bbox=([ 7.36 48.16  6.78]→[11.21 51.63 11.1 ]) level=0.0139
# [SHELL] chr12_12hrs_vacv_c0_q90.glb V=9218 F=18384 bbox=([ 6.98 48.11  6.71]→[11.72 51.7  11.16]) level=0.0091
# [SHELL] chr12_12hrs_vacv_c0_q80.glb V=12433 F=24882 bbox=([ 6.86 48.03  6.58]→[11.85 51.78 11.24]) level=0.0043
# [SHELL] chr12_12hrs_vacv_c0_q60.glb V=14259 F=28542 bbox=([ 6.68 47.9   6.4 ]→[12.03 51.92 11.41]) level=0.0006
# [SHELL] chr12_12hrs_vacv_c1_q95.glb V=5466 F=10868 bbox=([10.54 48.2   3.29]→[16.21 52.52  7.39]) level=0.0177
# [SHELL] chr12_12hrs_vacv_c1_q90.glb V=8521 F=16990 bbox=([10.43 48.13  3.2 ]→[16.3  52.57  7.56]) level=0.0115
# [SHELL] chr12_12hrs_vacv_c1_q80.glb V=11993 F=24012 bbox=([10.31 48.03  3.09]→[16.48 52.92  7.74]) level=0.0053
# [SHELL] chr12_12hrs_vacv_c1_q60.glb V=12900 F=25792 bbox=([10.12 47.86  2.9 ]→[16.7  53.14  7.96]) level=0.0007
# [SHELL] chr12_12hrs_vacv_c2_q95.glb V=4036 F=8012 bbox=([13.78 52.79  4.82]→[17.23 56.78  7.61]) level=0.0193
# [SHELL] chr12_12hrs_vacv_c2_q90.glb V=6922 F=13800 bbox=([13.7  52.71  4.76]→[17.3  56.82  7.77]) level=0.0113
# [SHELL] chr12_12hrs_vacv_c2_q80.glb V=10457 F=20930 bbox=([13.61 52.45  4.68]→[17.4  56.89  7.9 ]) level=0.0048
# [SHELL] chr12_12hrs_vacv_c2_q60.glb V=11879 F=23786 bbox=([13.46 52.26  4.55]→[17.57 57.01  8.07]) level=0.0007
# [OK] chr12_12hrs_vacv_aligned.json: pts=1091 clusters=3 noise=0.29 mcs=62 ms=31
# [DATA] chr12_18hrs_untr_aligned.json: JSON N=1091  CSV N=1091  (clustering on CSV; mapping by gene_name)
# [SHELL] chr12_18hrs_untr_c0_q95.glb V=8507 F=16930 bbox=([-69.27 -42.43 -96.35]→[-61.24 -33.68 -93.02]) level=0.0148
# [SHELL] chr12_18hrs_untr_c0_q90.glb V=13895 F=27738 bbox=([-69.37 -42.48 -96.42]→[-61.18 -33.61 -92.92]) level=0.0092
# [SHELL] chr12_18hrs_untr_c0_q80.glb V=18836 F=37688 bbox=([-69.48 -42.56 -96.52]→[-61.09 -33.52 -92.81]) level=0.0038
# [SHELL] chr12_18hrs_untr_c0_q60.glb V=22506 F=45022 bbox=([-69.66 -42.69 -96.71]→[-60.92 -33.34 -92.64]) level=0.0004
# [SHELL] chr12_18hrs_untr_c1_q95.glb V=4524 F=8996 bbox=([-63.89 -44.08 -97.96]→[-60.54 -39.24 -94.78]) level=0.0167
# [SHELL] chr12_18hrs_untr_c1_q90.glb V=7664 F=15260 bbox=([-63.96 -44.21 -98.07]→[-60.5  -38.86 -94.42]) level=0.0101
# [SHELL] chr12_18hrs_untr_c1_q80.glb V=10952 F=21924 bbox=([-64.04 -44.36 -98.18]→[-60.42 -38.68 -94.29]) level=0.0044
# [SHELL] chr12_18hrs_untr_c1_q60.glb V=12372 F=24756 bbox=([-64.22 -44.55 -98.37]→[-60.24 -38.48 -94.09]) level=0.0005
# [OK] chr12_18hrs_untr_aligned.json: pts=1091 clusters=2 noise=0.43 mcs=45 ms=22
# [DATA] chr12_18hrs_vacv_aligned.json: JSON N=1091  CSV N=1091  (clustering on CSV; mapping by gene_name)
# [SHELL] chr12_18hrs_vacv_c0_q95.glb V=4979 F=9894 bbox=([-27.98  33.75  28.62]→[-24.13  37.78  31.51]) level=0.0117
# [SHELL] chr12_18hrs_vacv_c0_q90.glb V=7926 F=15824 bbox=([-28.03  33.69  28.57]→[-24.09  37.95  31.56]) level=0.0077
# [SHELL] chr12_18hrs_vacv_c0_q80.glb V=10159 F=20334 bbox=([-28.12  33.6   28.47]→[-24.02  38.07  31.63]) level=0.0034
# [SHELL] chr12_18hrs_vacv_c0_q60.glb V=11370 F=22732 bbox=([-28.25  33.44  28.3 ]→[-23.88  38.24  31.77]) level=0.0004
# [SHELL] chr12_18hrs_vacv_c1_q95.glb V=7098 F=14128 bbox=([-25.58  37.96  29.99]→[-20.86  42.84  39.22]) level=0.0218
# [SHELL] chr12_18hrs_vacv_c1_q90.glb V=11216 F=22424 bbox=([-25.65  37.86  29.84]→[-20.72  42.93  39.27]) level=0.0129
# [SHELL] chr12_18hrs_vacv_c1_q80.glb V=15980 F=31976 bbox=([-25.76  37.74  29.51]→[-20.4   43.04  39.37]) level=0.0052
# [SHELL] chr12_18hrs_vacv_c1_q60.glb V=18726 F=37464 bbox=([-25.96  37.54  29.26]→[-20.15  43.22  39.55]) level=0.0006
# [OK] chr12_18hrs_vacv_aligned.json: pts=1091 clusters=2 noise=0.41 mcs=38 ms=19
# [DATA] chr12_24hrs_untr_aligned.json: JSON N=1091  CSV N=1091  (clustering on CSV; mapping by gene_name)
# [SHELL] chr12_24hrs_untr_c0_q95.glb V=4990 F=9948 bbox=([-57.22  36.55   3.1 ]→[-53.67  40.59   6.61]) level=0.0209
# [SHELL] chr12_24hrs_untr_c0_q90.glb V=7618 F=15228 bbox=([-57.35  36.45   3.05]→[-53.48  40.64   6.67]) level=0.0138
# [SHELL] chr12_24hrs_untr_c0_q80.glb V=10603 F=21228 bbox=([-57.47  36.34   2.91]→[-53.32  40.73   6.76]) level=0.0067
# [SHELL] chr12_24hrs_untr_c0_q60.glb V=11001 F=22012 bbox=([-57.65  36.17   2.69]→[-53.11  40.88   6.91]) level=0.0010
# [SHELL] chr12_24hrs_untr_c1_q95.glb V=7887 F=15690 bbox=([-57.26  31.79   4.57]→[-50.58  39.55   9.07]) level=0.0249
# [SHELL] chr12_24hrs_untr_c1_q90.glb V=12304 F=24606 bbox=([-57.33  31.69   4.46]→[-50.51  39.71   9.37]) level=0.0167
# [SHELL] chr12_24hrs_untr_c1_q80.glb V=16955 F=33970 bbox=([-57.43  31.58   4.02]→[-50.41  39.9    9.67]) level=0.0083
# [SHELL] chr12_24hrs_untr_c1_q60.glb V=17668 F=35340 bbox=([-57.67  31.37   3.72]→[-50.2   40.21   9.95]) level=0.0012
# [OK] chr12_24hrs_untr_aligned.json: pts=1091 clusters=2 noise=0.13 mcs=20 ms=10
# [DATA] chr12_24hrs_vacv_aligned.json: JSON N=1091  CSV N=1091  (clustering on CSV; mapping by gene_name)
# [SHELL] chr12_24hrs_vacv_c0_q95.glb V=1106 F=2192 bbox=([18.45 57.17 83.33]→[20.03 58.1  85.42]) level=0.0067
# [SHELL] chr12_24hrs_vacv_c0_q90.glb V=1782 F=3552 bbox=([18.38 57.11 83.26]→[20.11 58.19 85.5 ]) level=0.0029
# [SHELL] chr12_24hrs_vacv_c0_q80.glb V=2762 F=5516 bbox=([18.29 57.03 83.18]→[20.2  58.28 85.59]) level=0.0007
# [SHELL] chr12_24hrs_vacv_c0_q60.glb V=3790 F=7576 bbox=([18.18 56.92 83.07]→[20.32 58.39 85.7 ]) level=0.0001
# [SHELL] chr12_24hrs_vacv_c1_q95.glb V=1496 F=2972 bbox=([19.23 59.63 81.71]→[21.29 60.94 83.54]) level=0.0089
# [SHELL] chr12_24hrs_vacv_c1_q90.glb V=2487 F=4968 bbox=([19.16 59.55 81.63]→[21.37 61.02 83.62]) level=0.0048
# [SHELL] chr12_24hrs_vacv_c1_q80.glb V=3569 F=7140 bbox=([19.07 59.44 81.53]→[21.48 61.12 83.72]) level=0.0013
# [SHELL] chr12_24hrs_vacv_c1_q60.glb V=4744 F=9496 bbox=([18.93 59.3  81.39]→[21.62 61.26 83.87]) level=0.0001
# [SHELL] chr12_24hrs_vacv_c2_q95.glb V=3256 F=6496 bbox=([19.15 57.95 81.78]→[21.84 59.82 84.5 ]) level=0.0120
# [SHELL] chr12_24hrs_vacv_c2_q90.glb V=5072 F=10152 bbox=([18.76 57.9  81.56]→[21.89 59.87 84.66]) level=0.0077
# [SHELL] chr12_24hrs_vacv_c2_q80.glb V=6392 F=12792 bbox=([18.66 57.83 81.45]→[21.97 59.96 84.77]) level=0.0032
# [SHELL] chr12_24hrs_vacv_c2_q60.glb V=7305 F=14612 bbox=([18.49 57.68 81.29]→[22.12 60.12 84.93]) level=0.0003
# [SHELL] chr12_24hrs_vacv_c3_q95.glb V=1618 F=3220 bbox=([13.   57.55 88.9 ]→[14.41 58.8  90.93]) level=0.0177
# [SHELL] chr12_24hrs_vacv_c3_q90.glb V=2518 F=5024 bbox=([12.78 57.5  88.85]→[14.7  58.85 91.  ]) level=0.0097
# [SHELL] chr12_24hrs_vacv_c3_q80.glb V=3246 F=6492 bbox=([12.67 57.42 88.76]→[14.85 58.93 91.08]) level=0.0032
# [SHELL] chr12_24hrs_vacv_c3_q60.glb V=4416 F=8828 bbox=([12.49 57.27 88.6 ]→[15.02 59.07 91.23]) level=0.0002
# [SHELL] chr12_24hrs_vacv_c4_q95.glb V=3184 F=6340 bbox=([14.82 57.67 83.9 ]→[18.13 59.99 87.09]) level=0.0142
# [SHELL] chr12_24hrs_vacv_c4_q90.glb V=4842 F=9664 bbox=([14.72 57.61 83.83]→[18.23 60.06 87.16]) level=0.0085
# [SHELL] chr12_24hrs_vacv_c4_q80.glb V=6538 F=13092 bbox=([14.57 57.51 83.73]→[18.34 60.17 87.25]) level=0.0030
# [SHELL] chr12_24hrs_vacv_c4_q60.glb V=8285 F=16572 bbox=([14.39 57.35 83.56]→[18.52 60.35 87.42]) level=0.0002
# [SHELL] chr12_24hrs_vacv_c5_q95.glb V=1062 F=2112 bbox=([15.05 56.68 85.52]→[16.32 57.69 87.47]) level=0.0092
# [SHELL] chr12_24hrs_vacv_c5_q90.glb V=1606 F=3208 bbox=([14.95 56.6  85.42]→[16.39 57.75 87.54]) level=0.0044
# [SHELL] chr12_24hrs_vacv_c5_q80.glb V=2286 F=4568 bbox=([14.85 56.51 85.32]→[16.49 57.84 87.63]) level=0.0010
# [SHELL] chr12_24hrs_vacv_c5_q60.glb V=3254 F=6504 bbox=([14.71 56.37 85.18]→[16.61 57.97 87.76]) level=0.0001
# [SHELL] chr12_24hrs_vacv_c6_q95.glb V=1548 F=3084 bbox=([13.74 59.17 85.58]→[15.55 60.4  87.31]) level=0.0111
# [SHELL] chr12_24hrs_vacv_c6_q90.glb V=2363 F=4732 bbox=([13.7  59.12 85.46]→[15.62 60.45 87.9 ]) level=0.0063
# [SHELL] chr12_24hrs_vacv_c6_q80.glb V=3130 F=6256 bbox=([13.63 59.03 85.35]→[15.72 60.53 88.01]) level=0.0020
# [SHELL] chr12_24hrs_vacv_c6_q60.glb V=4272 F=8544 bbox=([13.5  58.89 85.19]→[15.87 60.67 88.17]) level=0.0001
# [SHELL] chr12_24hrs_vacv_c7_q95.glb V=1130 F=2256 bbox=([11.73 58.25 88.01]→[12.85 59.69 89.4 ]) level=0.0134
# [SHELL] chr12_24hrs_vacv_c7_q90.glb V=1730 F=3456 bbox=([11.62 58.17 87.75]→[13.41 59.78 89.67]) level=0.0069
# [SHELL] chr12_24hrs_vacv_c7_q80.glb V=2584 F=5168 bbox=([11.5  58.07 87.61]→[13.55 59.91 89.8 ]) level=0.0018
# [SHELL] chr12_24hrs_vacv_c7_q60.glb V=3772 F=7544 bbox=([11.34 57.92 87.44]→[13.72 60.07 89.97]) level=0.0001
# [SHELL] chr12_24hrs_vacv_c8_q95.glb V=2122 F=4228 bbox=([12.34 58.27 87.76]→[15.47 60.66 90.42]) level=0.0116
# [SHELL] chr12_24hrs_vacv_c8_q90.glb V=3234 F=6470 bbox=([12.28 58.21 87.64]→[15.52 60.79 90.55]) level=0.0062
# [SHELL] chr12_24hrs_vacv_c8_q80.glb V=4460 F=8920 bbox=([12.18 58.12 87.52]→[15.62 60.92 90.68]) level=0.0017
# [SHELL] chr12_24hrs_vacv_c8_q60.glb V=6258 F=12516 bbox=([12.03 57.98 87.34]→[15.76 61.1  90.86]) level=0.0001
# [OK] chr12_24hrs_vacv_aligned.json: pts=1091 clusters=9 noise=0.49 mcs=20 ms=10
#
# === chr13 ===
# [DATA] chr13_12hrs_untr_aligned.json: JSON N=854  CSV N=854  (clustering on CSV; mapping by gene_name)
# [SHELL] chr13_12hrs_untr_c0_q95.glb V=5260 F=10464 bbox=([-10.5   37.4  -62.18]→[ -6.48  41.48 -58.9 ]) level=0.0133
# [SHELL] chr13_12hrs_untr_c0_q90.glb V=8970 F=17868 bbox=([-10.73  37.33 -62.26]→[ -6.4   41.56 -58.83]) level=0.0085
# [SHELL] chr13_12hrs_untr_c0_q80.glb V=12477 F=24984 bbox=([-10.86  37.23 -62.35]→[ -6.28  41.65 -58.71]) level=0.0039
# [SHELL] chr13_12hrs_untr_c0_q60.glb V=13891 F=27802 bbox=([-11.03  37.06 -62.51]→[ -6.11  41.81 -58.53]) level=0.0006
# [SHELL] chr13_12hrs_untr_c1_q95.glb V=8186 F=16252 bbox=([ -9.99  32.58 -63.65]→[ -3.88  40.25 -55.47]) level=0.0232
# [SHELL] chr13_12hrs_untr_c1_q90.glb V=13350 F=26668 bbox=([-10.33  32.51 -63.74]→[ -3.57  40.35 -55.4 ]) level=0.0156
# [SHELL] chr13_12hrs_untr_c1_q80.glb V=18958 F=37988 bbox=([-10.48  32.19 -63.92]→[ -3.35  40.47 -55.29]) level=0.0082
# [SHELL] chr13_12hrs_untr_c1_q60.glb V=18439 F=36878 bbox=([-10.77  31.89 -64.17]→[ -3.08  40.67 -55.09]) level=0.0015
# [OK] chr13_12hrs_untr_aligned.json: pts=854 clusters=2 noise=0.01 mcs=18 ms=9
# [DATA] chr13_12hrs_vacv_aligned.json: JSON N=854  CSV N=854  (clustering on CSV; mapping by gene_name)
# [SHELL] chr13_12hrs_vacv_c0_q95.glb V=7168 F=14224 bbox=([-37.35  14.9   65.68]→[-31.59  20.05  68.6 ]) level=0.0118
# [SHELL] chr13_12hrs_vacv_c0_q90.glb V=11562 F=23068 bbox=([-37.41  14.85  65.49]→[-31.52  20.12  68.69]) level=0.0073
# [SHELL] chr13_12hrs_vacv_c0_q80.glb V=15664 F=31324 bbox=([-37.5   14.78  65.37]→[-31.43  20.21  68.81]) level=0.0030
# [SHELL] chr13_12hrs_vacv_c0_q60.glb V=18734 F=37488 bbox=([-37.64  14.64  65.19]→[-31.29  20.37  68.98]) level=0.0004
# [SHELL] chr13_12hrs_vacv_c1_q95.glb V=9480 F=18840 bbox=([-42.58  15.19  66.98]→[-36.43  23.87  73.29]) level=0.0187
# [SHELL] chr13_12hrs_vacv_c1_q90.glb V=15135 F=30214 bbox=([-42.72  14.91  66.79]→[-36.36  23.97  73.41]) level=0.0124
# [SHELL] chr13_12hrs_vacv_c1_q80.glb V=22085 F=44222 bbox=([-42.84  14.55  66.6 ]→[-36.27  24.09  73.55]) level=0.0061
# [SHELL] chr13_12hrs_vacv_c1_q60.glb V=23126 F=46288 bbox=([-43.03  14.31  66.37]→[-36.11  24.28  73.73]) level=0.0012
# [OK] chr13_12hrs_vacv_aligned.json: pts=854 clusters=2 noise=0.09 mcs=46 ms=None
# [DATA] chr13_18hrs_untr_aligned.json: JSON N=854  CSV N=854  (clustering on CSV; mapping by gene_name)
# [SHELL] chr13_18hrs_untr_c0_q95.glb V=4306 F=8572 bbox=([ 29.17  16.69 -14.24]→[ 32.52  21.23 -10.85]) level=0.0140
# [SHELL] chr13_18hrs_untr_c0_q90.glb V=6750 F=13480 bbox=([ 29.1  16.6 -14.3]→[ 32.94  21.37 -10.59]) level=0.0089
# [SHELL] chr13_18hrs_untr_c0_q80.glb V=8873 F=17776 bbox=([ 29.01  16.5  -14.44]→[ 33.08  21.52 -10.44]) level=0.0037
# [SHELL] chr13_18hrs_untr_c0_q60.glb V=10280 F=20560 bbox=([ 28.85  16.31 -14.64]→[ 33.29  21.73 -10.23]) level=0.0004
# [SHELL] chr13_18hrs_untr_c1_q95.glb V=8632 F=17132 bbox=([ 27.69  19.75 -17.94]→[ 33.03  26.95 -10.42]) level=0.0169
# [SHELL] chr13_18hrs_untr_c1_q90.glb V=14405 F=28698 bbox=([ 27.63  19.04 -18.07]→[ 33.11  27.01 -10.34]) level=0.0106
# [SHELL] chr13_18hrs_untr_c1_q80.glb V=21392 F=42808 bbox=([ 27.54  18.81 -18.19]→[ 33.2   27.1  -10.23]) level=0.0048
# [SHELL] chr13_18hrs_untr_c1_q60.glb V=23947 F=47902 bbox=([ 27.39  18.59 -18.39]→[ 33.37  27.26 -10.04]) level=0.0007
# [OK] chr13_18hrs_untr_aligned.json: pts=854 clusters=2 noise=0.25 mcs=29 ms=14
# [DATA] chr13_18hrs_vacv_aligned.json: JSON N=854  CSV N=854  (clustering on CSV; mapping by gene_name)
# [SHELL] chr13_18hrs_vacv_c0_q95.glb V=9142 F=18148 bbox=([-17.58 -33.05 -33.85]→[-12.38 -27.63 -26.46]) level=0.0165
# [SHELL] chr13_18hrs_vacv_c0_q90.glb V=14524 F=28920 bbox=([-17.66 -33.23 -33.94]→[-12.3  -27.42 -26.4 ]) level=0.0107
# [SHELL] chr13_18hrs_vacv_c0_q80.glb V=21540 F=43100 bbox=([-17.76 -33.43 -34.07]→[-12.18 -27.18 -26.31]) level=0.0052
# [SHELL] chr13_18hrs_vacv_c0_q60.glb V=23068 F=46168 bbox=([-17.93 -33.63 -34.26]→[-12.   -26.98 -26.16]) level=0.0010
# [SHELL] chr13_18hrs_vacv_c1_q95.glb V=1928 F=3832 bbox=([-15.   -27.91 -28.95]→[-13.42 -25.27 -26.55]) level=0.0071
# [SHELL] chr13_18hrs_vacv_c1_q90.glb V=2960 F=5904 bbox=([-15.07 -27.98 -29.01]→[-13.34 -25.19 -26.47]) level=0.0036
# [SHELL] chr13_18hrs_vacv_c1_q80.glb V=4146 F=8292 bbox=([-15.15 -28.06 -29.09]→[-13.25 -25.1  -26.38]) level=0.0011
# [SHELL] chr13_18hrs_vacv_c1_q60.glb V=5612 F=11220 bbox=([-15.29 -28.2  -29.21]→[-13.1  -24.95 -26.23]) level=0.0001
# [SHELL] chr13_18hrs_vacv_c2_q95.glb V=6354 F=12640 bbox=([-15.8  -31.01 -28.68]→[-11.48 -25.72 -22.54]) level=0.0141
# [SHELL] chr13_18hrs_vacv_c2_q90.glb V=10150 F=20256 bbox=([-15.86 -31.16 -29.03]→[-11.34 -25.37 -22.36]) level=0.0091
# [SHELL] chr13_18hrs_vacv_c2_q80.glb V=13852 F=27728 bbox=([-15.96 -31.3  -29.2 ]→[-11.17 -25.21 -22.2 ]) level=0.0039
# [SHELL] chr13_18hrs_vacv_c2_q60.glb V=16104 F=32224 bbox=([-16.13 -31.51 -29.41]→[-10.96 -24.99 -21.99]) level=0.0005
# [OK] chr13_18hrs_vacv_aligned.json: pts=854 clusters=3 noise=0.12 mcs=18 ms=9
# [DATA] chr13_24hrs_untr_aligned.json: JSON N=854  CSV N=854  (clustering on CSV; mapping by gene_name)
# [SHELL] chr13_24hrs_untr_c0_q95.glb V=5323 F=10572 bbox=([-50.99 -45.97  -4.69]→[-47.56 -41.74  -0.93]) level=0.0135
# [SHELL] chr13_24hrs_untr_c0_q90.glb V=8927 F=17816 bbox=([-51.05 -46.15  -4.74]→[-47.36 -41.66  -0.86]) level=0.0091
# [SHELL] chr13_24hrs_untr_c0_q80.glb V=11982 F=24000 bbox=([-51.14 -46.26  -4.81]→[-47.23 -41.52  -0.77]) level=0.0045
# [SHELL] chr13_24hrs_untr_c0_q60.glb V=12491 F=25006 bbox=([-51.3  -46.44  -4.99]→[-47.05 -41.34  -0.61]) level=0.0007
# [SHELL] chr13_24hrs_untr_c1_q95.glb V=9197 F=18284 bbox=([-50.28 -50.19  -5.31]→[-45.49 -45.43   2.1 ]) level=0.0197
# [SHELL] chr13_24hrs_untr_c1_q90.glb V=14454 F=28888 bbox=([-50.38 -50.28  -5.45]→[-45.35 -45.32   2.26]) level=0.0128
# [SHELL] chr13_24hrs_untr_c1_q80.glb V=20416 F=40868 bbox=([-50.48 -50.42  -5.95]→[-45.22 -44.95   2.46]) level=0.0062
# [SHELL] chr13_24hrs_untr_c1_q60.glb V=22003 F=44042 bbox=([-50.7  -50.65  -6.18]→[-44.99 -44.72   2.68]) level=0.0010
# [OK] chr13_24hrs_untr_aligned.json: pts=854 clusters=2 noise=0.11 mcs=18 ms=9
# [DATA] chr13_24hrs_vacv_aligned.json: JSON N=854  CSV N=854  (clustering on CSV; mapping by gene_name)
# [SHELL] chr13_24hrs_vacv_c0_q95.glb V=5457 F=10854 bbox=([-68.26   4.95  -9.7 ]→[-64.71   8.69  -6.08]) level=0.0143
# [SHELL] chr13_24hrs_vacv_c0_q90.glb V=8481 F=16950 bbox=([-68.37   4.21  -9.79]→[-64.65   8.88  -5.89]) level=0.0095
# [SHELL] chr13_24hrs_vacv_c0_q80.glb V=11368 F=22752 bbox=([-68.52   4.05  -9.93]→[-64.57   9.02  -5.74]) level=0.0044
# [SHELL] chr13_24hrs_vacv_c0_q60.glb V=12488 F=24984 bbox=([-68.71   3.86 -10.13]→[-64.4    9.21  -5.55]) level=0.0006
# [SHELL] chr13_24hrs_vacv_c1_q95.glb V=7883 F=15684 bbox=([-69.73   0.13 -11.59]→[-62.94   6.16  -4.49]) level=0.0225
# [SHELL] chr13_24hrs_vacv_c1_q90.glb V=12328 F=24636 bbox=([-6.986e+01 -1.000e-02 -1.170e+01]→[-62.84   6.24  -4.34]) level=0.0149
# [SHELL] chr13_24hrs_vacv_c1_q80.glb V=17682 F=35412 bbox=([-69.99  -0.14 -11.84]→[-62.7    6.35  -4.03]) level=0.0075
# [SHELL] chr13_24hrs_vacv_c1_q60.glb V=18195 F=36382 bbox=([-70.2   -0.36 -12.06]→[-62.46   6.55  -3.78]) level=0.0012
# [OK] chr13_24hrs_vacv_aligned.json: pts=854 clusters=2 noise=0.08 mcs=18 ms=9
#
# === chr14 ===
# [DATA] chr14_12hrs_untr_aligned.json: JSON N=1159  CSV N=1159  (clustering on CSV; mapping by gene_name)
# [SHELL] chr14_12hrs_untr_c0_q95.glb V=3360 F=6700 bbox=([28.96 15.19 42.47]→[32.16 18.26 45.62]) level=0.0180
# [SHELL] chr14_12hrs_untr_c0_q90.glb V=5170 F=10348 bbox=([28.7  15.11 42.36]→[32.24 18.45 45.71]) level=0.0120
# [SHELL] chr14_12hrs_untr_c0_q80.glb V=6625 F=13254 bbox=([28.56 14.99 42.24]→[32.35 18.63 45.84]) level=0.0052
# [SHELL] chr14_12hrs_untr_c0_q60.glb V=8096 F=16188 bbox=([28.34 14.77 42.03]→[32.55 18.86 46.05]) level=0.0004
# [SHELL] chr14_12hrs_untr_c1_q95.glb V=2366 F=4716 bbox=([30.85 17.79 44.03]→[32.87 20.82 46.57]) level=0.0158
# [SHELL] chr14_12hrs_untr_c1_q90.glb V=3756 F=7496 bbox=([30.75 17.72 43.97]→[32.94 20.9  46.63]) level=0.0090
# [SHELL] chr14_12hrs_untr_c1_q80.glb V=5314 F=10624 bbox=([30.64 17.62 43.85]→[33.05 21.02 46.73]) level=0.0030
# [SHELL] chr14_12hrs_untr_c1_q60.glb V=6806 F=13608 bbox=([30.47 17.46 43.68]→[33.21 21.2  46.89]) level=0.0002
# [SHELL] chr14_12hrs_untr_c2_q95.glb V=2216 F=4412 bbox=([32.47 17.17 46.32]→[34.43 19.42 49.37]) level=0.0133
# [SHELL] chr14_12hrs_untr_c2_q90.glb V=3398 F=6788 bbox=([32.06 17.09 46.25]→[34.5  19.77 49.44]) level=0.0078
# [SHELL] chr14_12hrs_untr_c2_q80.glb V=4646 F=9288 bbox=([31.92 16.98 46.14]→[34.61 19.92 49.53]) level=0.0025
# [SHELL] chr14_12hrs_untr_c2_q60.glb V=6306 F=12672 bbox=([31.73 16.81 45.98]→[34.77 20.1  49.7 ]) level=0.0002
# [SHELL] chr14_12hrs_untr_c3_q95.glb V=1540 F=3064 bbox=([30.99 17.78 46.56]→[32.9  20.56 48.06]) level=0.0094
# [SHELL] chr14_12hrs_untr_c3_q90.glb V=2330 F=4656 bbox=([30.89 17.7  46.46]→[32.96 20.65 48.13]) level=0.0050
# [SHELL] chr14_12hrs_untr_c3_q80.glb V=3166 F=6332 bbox=([30.77 17.58 46.35]→[33.05 20.77 48.23]) level=0.0013
# [SHELL] chr14_12hrs_untr_c3_q60.glb V=4448 F=8896 bbox=([30.61 17.43 46.19]→[33.2  20.93 48.39]) level=0.0001
# [SHELL] chr14_12hrs_untr_c4_q95.glb V=1932 F=3844 bbox=([31.99 15.86 45.74]→[34.65 17.74 48.08]) level=0.0155
# [SHELL] chr14_12hrs_untr_c4_q90.glb V=2894 F=5784 bbox=([31.9  15.77 45.65]→[34.72 17.81 48.2 ]) level=0.0085
# [SHELL] chr14_12hrs_untr_c4_q80.glb V=4014 F=8024 bbox=([31.78 15.64 45.53]→[34.83 17.91 48.34]) level=0.0025
# [SHELL] chr14_12hrs_untr_c4_q60.glb V=5610 F=11216 bbox=([31.6  15.45 45.36]→[35.   18.07 48.52]) level=0.0001
# [SHELL] chr14_12hrs_untr_c5_q95.glb V=1072 F=2128 bbox=([32.78 14.83 48.09]→[34.45 15.77 49.2 ]) level=0.0084
# [SHELL] chr14_12hrs_untr_c5_q90.glb V=1578 F=3156 bbox=([32.73 14.78 48.03]→[34.5  15.82 49.25]) level=0.0047
# [SHELL] chr14_12hrs_untr_c5_q80.glb V=2048 F=4092 bbox=([32.65 14.7  47.93]→[34.58 15.9  49.33]) level=0.0013
# [SHELL] chr14_12hrs_untr_c5_q60.glb V=2900 F=5796 bbox=([32.52 14.57 47.79]→[34.7  16.03 49.46]) level=0.0001
# [SHELL] chr14_12hrs_untr_c6_q95.glb V=1428 F=2848 bbox=([31.02 14.1  46.97]→[32.93 15.49 48.44]) level=0.0162
# [SHELL] chr14_12hrs_untr_c6_q90.glb V=2150 F=4292 bbox=([30.8  14.01 46.89]→[33.14 15.56 48.51]) level=0.0088
# [SHELL] chr14_12hrs_untr_c6_q80.glb V=3112 F=6220 bbox=([30.66 13.89 46.79]→[33.29 15.68 48.63]) level=0.0025
# [SHELL] chr14_12hrs_untr_c6_q60.glb V=4462 F=8920 bbox=([30.48 13.71 46.63]→[33.47 15.85 48.8 ]) level=0.0001
# [OK] chr14_12hrs_untr_aligned.json: pts=1159 clusters=7 noise=0.49 mcs=20 ms=10
# [DATA] chr14_12hrs_vacv_aligned.json: JSON N=1159  CSV N=1159  (clustering on CSV; mapping by gene_name)
# [SHELL] chr14_12hrs_vacv_c0_q95.glb V=4050 F=8032 bbox=([  7.32 -55.61 -35.34]→[ 10.65 -52.44 -31.27]) level=0.0158
# [SHELL] chr14_12hrs_vacv_c0_q90.glb V=6710 F=13376 bbox=([  7.25 -55.71 -35.49]→[ 10.72 -52.4  -31.21]) level=0.0099
# [SHELL] chr14_12hrs_vacv_c0_q80.glb V=9322 F=18676 bbox=([  7.15 -55.82 -35.63]→[ 10.81 -52.32 -31.14]) level=0.0044
# [SHELL] chr14_12hrs_vacv_c0_q60.glb V=10467 F=20948 bbox=([  6.98 -56.   -35.82]→[ 10.97 -52.19 -30.99]) level=0.0005
# [SHELL] chr14_12hrs_vacv_c1_q95.glb V=2830 F=5636 bbox=([  5.08 -56.98 -37.17]→[  7.93 -54.49 -33.86]) level=0.0138
# [SHELL] chr14_12hrs_vacv_c1_q90.glb V=4506 F=9004 bbox=([  4.83 -57.07 -37.45]→[  8.19 -54.44 -33.81]) level=0.0078
# [SHELL] chr14_12hrs_vacv_c1_q80.glb V=6291 F=12576 bbox=([  4.69 -57.21 -37.6 ]→[  8.33 -54.32 -33.73]) level=0.0024
# [SHELL] chr14_12hrs_vacv_c1_q60.glb V=8580 F=17164 bbox=([  4.51 -57.38 -37.78]→[  8.52 -54.16 -33.58]) level=0.0002
# [SHELL] chr14_12hrs_vacv_c2_q95.glb V=1248 F=2480 bbox=([  2.75 -57.89 -36.97]→[  4.26 -56.67 -35.21]) level=0.0140
# [SHELL] chr14_12hrs_vacv_c2_q90.glb V=2036 F=4068 bbox=([  2.57 -57.94 -37.04]→[  4.33 -56.62 -35.15]) level=0.0077
# [SHELL] chr14_12hrs_vacv_c2_q80.glb V=2812 F=5620 bbox=([  2.45 -58.02 -37.13]→[  4.45 -56.53 -35.06]) level=0.0023
# [SHELL] chr14_12hrs_vacv_c2_q60.glb V=3712 F=7420 bbox=([  2.29 -58.15 -37.28]→[  4.61 -56.38 -34.91]) level=0.0001
# [SHELL] chr14_12hrs_vacv_c3_q95.glb V=2710 F=5392 bbox=([  2.17 -58.25 -40.69]→[  4.77 -56.72 -37.73]) level=0.0149
# [SHELL] chr14_12hrs_vacv_c3_q90.glb V=4090 F=8180 bbox=([  1.91 -58.34 -40.75]→[  4.82 -56.63 -37.66]) level=0.0090
# [SHELL] chr14_12hrs_vacv_c3_q80.glb V=5524 F=11048 bbox=([  1.79 -58.45 -40.84]→[  4.91 -56.52 -37.56]) level=0.0030
# [SHELL] chr14_12hrs_vacv_c3_q60.glb V=7168 F=14332 bbox=([  1.62 -58.61 -41.  ]→[  5.06 -56.36 -37.41]) level=0.0002
# [SHELL] chr14_12hrs_vacv_c4_q95.glb V=1518 F=3000 bbox=([  1.76 -55.82 -37.36]→[  4.15 -54.46 -34.98]) level=0.0094
# [SHELL] chr14_12hrs_vacv_c4_q90.glb V=2616 F=5220 bbox=([  1.66 -55.92 -37.46]→[  4.25 -54.4  -34.88]) level=0.0048
# [SHELL] chr14_12hrs_vacv_c4_q80.glb V=3632 F=7264 bbox=([  1.55 -56.03 -37.57]→[  4.36 -54.3  -34.77]) level=0.0013
# [SHELL] chr14_12hrs_vacv_c4_q60.glb V=4961 F=9920 bbox=([  1.4  -56.18 -37.72]→[  4.51 -54.18 -34.62]) level=0.0001
# [SHELL] chr14_12hrs_vacv_c5_q95.glb V=2342 F=4656 bbox=([  1.56 -56.71 -40.1 ]→[  4.25 -55.27 -36.79]) level=0.0107
# [SHELL] chr14_12hrs_vacv_c5_q90.glb V=3466 F=6920 bbox=([  1.43 -56.79 -40.18]→[  4.31 -55.19 -36.74]) level=0.0059
# [SHELL] chr14_12hrs_vacv_c5_q80.glb V=4684 F=9360 bbox=([  1.31 -56.9  -40.29]→[  4.41 -55.08 -36.65]) level=0.0017
# [SHELL] chr14_12hrs_vacv_c5_q60.glb V=6690 F=13376 bbox=([  1.16 -57.05 -40.43]→[  4.55 -54.93 -36.51]) level=0.0001
# [OK] chr14_12hrs_vacv_aligned.json: pts=1159 clusters=6 noise=0.49 mcs=33 ms=16
# [DATA] chr14_18hrs_untr_aligned.json: JSON N=1159  CSV N=1159  (clustering on CSV; mapping by gene_name)
# [SHELL] chr14_18hrs_untr_c0_q95.glb V=2960 F=5904 bbox=([ 39.2  -26.72 -39.17]→[ 42.27 -23.95 -36.59]) level=0.0123
# [SHELL] chr14_18hrs_untr_c0_q90.glb V=4802 F=9596 bbox=([ 39.06 -26.83 -39.22]→[ 42.32 -23.85 -36.48]) level=0.0074
# [SHELL] chr14_18hrs_untr_c0_q80.glb V=6560 F=13112 bbox=([ 38.94 -26.94 -39.3 ]→[ 42.41 -23.73 -36.36]) level=0.0027
# [SHELL] chr14_18hrs_untr_c0_q60.glb V=8358 F=16720 bbox=([ 38.77 -27.11 -39.45]→[ 42.56 -23.56 -36.19]) level=0.0002
# [SHELL] chr14_18hrs_untr_c1_q95.glb V=3184 F=6340 bbox=([ 35.89 -28.13 -35.05]→[ 38.54 -23.36 -32.16]) level=0.0125
# [SHELL] chr14_18hrs_untr_c1_q90.glb V=5200 F=10374 bbox=([ 35.79 -28.78 -35.11]→[ 38.6  -23.27 -32.08]) level=0.0067
# [SHELL] chr14_18hrs_untr_c1_q80.glb V=7496 F=14980 bbox=([ 35.67 -28.92 -35.19]→[ 38.69 -23.15 -31.97]) level=0.0021
# [SHELL] chr14_18hrs_untr_c1_q60.glb V=10046 F=20096 bbox=([ 35.48 -29.1  -35.34]→[ 38.85 -22.97 -31.79]) level=0.0001
# [SHELL] chr14_18hrs_untr_c2_q95.glb V=3088 F=6148 bbox=([ 37.37 -29.11 -37.18]→[ 41.13 -26.62 -33.31]) level=0.0133
# [SHELL] chr14_18hrs_untr_c2_q90.glb V=5023 F=10018 bbox=([ 37.28 -29.38 -37.25]→[ 41.26 -26.52 -33.09]) level=0.0076
# [SHELL] chr14_18hrs_untr_c2_q80.glb V=7134 F=14272 bbox=([ 37.17 -29.52 -37.34]→[ 41.4  -26.4  -32.96]) level=0.0025
# [SHELL] chr14_18hrs_untr_c2_q60.glb V=9510 F=19164 bbox=([ 37.   -29.7  -37.51]→[ 41.58 -26.22 -32.78]) level=0.0002
# [OK] chr14_18hrs_untr_aligned.json: pts=1159 clusters=3 noise=0.69 mcs=46 ms=23
# [DATA] chr14_18hrs_vacv_aligned.json: JSON N=1159  CSV N=1159  (clustering on CSV; mapping by gene_name)
# [SHELL] chr14_18hrs_vacv_c0_q95.glb V=4142 F=8232 bbox=([-42.63   9.77 -11.31]→[-39.24  12.6   -8.02]) level=0.0171
# [SHELL] chr14_18hrs_vacv_c0_q90.glb V=6538 F=13036 bbox=([-42.7    9.7  -11.39]→[-39.15  12.86  -7.95]) level=0.0114
# [SHELL] chr14_18hrs_vacv_c0_q80.glb V=9236 F=18484 bbox=([-42.85   9.6  -11.5 ]→[-39.05  13.23  -7.86]) level=0.0052
# [SHELL] chr14_18hrs_vacv_c0_q60.glb V=10117 F=20246 bbox=([-43.04   9.43 -11.68]→[-38.87  13.43  -7.68]) level=0.0007
# [SHELL] chr14_18hrs_vacv_c1_q95.glb V=10418 F=20716 bbox=([-39.47   7.85 -14.07]→[-30.57  13.58  -9.6 ]) level=0.0221
# [SHELL] chr14_18hrs_vacv_c1_q90.glb V=16360 F=32680 bbox=([-39.52   7.7  -14.17]→[-30.51  13.69  -9.38]) level=0.0148
# [SHELL] chr14_18hrs_vacv_c1_q80.glb V=22932 F=45876 bbox=([-39.6    7.58 -14.29]→[-30.43  13.83  -9.23]) level=0.0073
# [SHELL] chr14_18hrs_vacv_c1_q60.glb V=25716 F=51468 bbox=([-39.73   7.39 -14.46]→[-30.28  14.03  -9.04]) level=0.0013
# [OK] chr14_18hrs_vacv_aligned.json: pts=1159 clusters=2 noise=0.19 mcs=33 ms=16
# [DATA] chr14_24hrs_untr_aligned.json: JSON N=1159  CSV N=1159  (clustering on CSV; mapping by gene_name)
# [SHELL] chr14_24hrs_untr_c0_q95.glb V=1506 F=3008 bbox=([ 49.31 -21.57 -42.77]→[ 50.95 -20.25 -41.8 ]) level=0.0122
# [SHELL] chr14_24hrs_untr_c0_q90.glb V=2180 F=4352 bbox=([ 49.25 -21.62 -42.82]→[ 51.03 -19.64 -41.73]) level=0.0070
# [SHELL] chr14_24hrs_untr_c0_q80.glb V=3056 F=6108 bbox=([ 49.17 -21.7  -42.91]→[ 51.14 -19.52 -41.63]) level=0.0022
# [SHELL] chr14_24hrs_untr_c0_q60.glb V=4146 F=8288 bbox=([ 49.02 -21.84 -43.05]→[ 51.29 -19.37 -41.49]) level=0.0001
# [SHELL] chr14_24hrs_untr_c1_q95.glb V=781 F=1556 bbox=([ 53.19 -21.45 -42.89]→[ 54.26 -20.15 -42.12]) level=0.0144
# [SHELL] chr14_24hrs_untr_c1_q90.glb V=1159 F=2320 bbox=([ 53.1  -21.55 -42.99]→[ 54.34 -20.1  -42.07]) level=0.0073
# [SHELL] chr14_24hrs_untr_c1_q80.glb V=1754 F=3508 bbox=([ 52.98 -21.68 -43.11]→[ 54.46 -20.02 -41.98]) level=0.0016
# [SHELL] chr14_24hrs_untr_c1_q60.glb V=2618 F=5236 bbox=([ 52.83 -21.83 -43.26]→[ 54.61 -19.89 -41.82]) level=0.0001
# [SHELL] chr14_24hrs_untr_c2_q95.glb V=1516 F=3016 bbox=([ 50.66 -21.77 -43.97]→[ 52.83 -20.07 -42.72]) level=0.0111
# [SHELL] chr14_24hrs_untr_c2_q90.glb V=2228 F=4452 bbox=([ 50.55 -21.85 -44.35]→[ 52.87 -19.88 -42.58]) level=0.0061
# [SHELL] chr14_24hrs_untr_c2_q80.glb V=3056 F=6104 bbox=([ 50.42 -21.95 -44.48]→[ 52.95 -19.75 -42.45]) level=0.0017
# [SHELL] chr14_24hrs_untr_c2_q60.glb V=4332 F=8840 bbox=([ 50.26 -22.11 -44.64]→[ 53.1  -19.59 -42.29]) level=0.0001
# [SHELL] chr14_24hrs_untr_c3_q95.glb V=1709 F=3394 bbox=([ 52.58 -21.98 -45.27]→[ 54.82 -19.63 -43.58]) level=0.0081
# [SHELL] chr14_24hrs_untr_c3_q90.glb V=2664 F=5316 bbox=([ 52.5  -22.04 -45.35]→[ 54.89 -19.54 -43.5 ]) level=0.0044
# [SHELL] chr14_24hrs_untr_c3_q80.glb V=3554 F=7100 bbox=([ 52.39 -22.13 -45.46]→[ 54.99 -19.44 -43.4 ]) level=0.0013
# [SHELL] chr14_24hrs_untr_c3_q60.glb V=4752 F=9500 bbox=([ 52.24 -22.28 -45.61]→[ 55.14 -19.28 -43.25]) level=0.0001
# [SHELL] chr14_24hrs_untr_c4_q95.glb V=1334 F=2664 bbox=([ 53.1  -18.84 -44.5 ]→[ 54.92 -17.4  -43.37]) level=0.0171
# [SHELL] chr14_24hrs_untr_c4_q90.glb V=2198 F=4388 bbox=([ 53.02 -18.96 -44.77]→[ 55.   -17.35 -43.26]) level=0.0087
# [SHELL] chr14_24hrs_untr_c4_q80.glb V=3030 F=6056 bbox=([ 52.92 -19.09 -44.89]→[ 55.1  -17.27 -43.15]) level=0.0028
# [SHELL] chr14_24hrs_untr_c4_q60.glb V=4250 F=8496 bbox=([ 52.77 -19.26 -45.07]→[ 55.26 -17.1  -42.98]) level=0.0002
# [SHELL] chr14_24hrs_untr_c5_q95.glb V=928 F=1836 bbox=([ 52.82 -18.01 -42.24]→[ 53.84 -16.43 -40.97]) level=0.0094
# [SHELL] chr14_24hrs_untr_c5_q90.glb V=1592 F=3176 bbox=([ 52.76 -18.1  -42.34]→[ 53.93 -16.37 -40.87]) level=0.0045
# [SHELL] chr14_24hrs_untr_c5_q80.glb V=2193 F=4392 bbox=([ 52.68 -18.2  -42.43]→[ 54.03 -16.29 -40.77]) level=0.0013
# [SHELL] chr14_24hrs_untr_c5_q60.glb V=3012 F=6020 bbox=([ 52.55 -18.35 -42.58]→[ 54.17 -16.16 -40.62]) level=0.0001
# [SHELL] chr14_24hrs_untr_c6_q95.glb V=844 F=1688 bbox=([ 52.96 -17.67 -43.41]→[ 54.16 -16.62 -42.63]) level=0.0124
# [SHELL] chr14_24hrs_untr_c6_q90.glb V=1292 F=2576 bbox=([ 52.74 -17.72 -43.47]→[ 54.23 -16.05 -42.51]) level=0.0060
# [SHELL] chr14_24hrs_untr_c6_q80.glb V=2020 F=4036 bbox=([ 52.62 -17.81 -43.56]→[ 54.32 -15.93 -42.39]) level=0.0014
# [SHELL] chr14_24hrs_untr_c6_q60.glb V=2862 F=5840 bbox=([ 52.47 -17.94 -43.69]→[ 54.46 -15.78 -42.24]) level=0.0001
# [OK] chr14_24hrs_untr_aligned.json: pts=1159 clusters=7 noise=0.74 mcs=28 ms=None
# [DATA] chr14_24hrs_vacv_aligned.json: JSON N=1159  CSV N=1159  (clustering on CSV; mapping by gene_name)
# [SHELL] chr14_24hrs_vacv_c0_q95.glb V=4399 F=8766 bbox=([-66.37  10.43 -21.26]→[-63.32  13.61 -17.49]) level=0.0172
# [SHELL] chr14_24hrs_vacv_c0_q90.glb V=6596 F=13176 bbox=([-66.43  10.27 -21.33]→[-63.24  13.69 -17.4 ]) level=0.0114
# [SHELL] chr14_24hrs_vacv_c0_q80.glb V=8686 F=17376 bbox=([-66.52  10.12 -21.42]→[-63.14  13.8  -17.29]) level=0.0051
# [SHELL] chr14_24hrs_vacv_c0_q60.glb V=9852 F=19700 bbox=([-66.69   9.92 -21.59]→[-62.96  13.98 -17.11]) level=0.0006
# [SHELL] chr14_24hrs_vacv_c1_q95.glb V=7166 F=14276 bbox=([-64.02   6.92 -19.18]→[-59.21  14.16 -14.64]) level=0.0296
# [SHELL] chr14_24hrs_vacv_c1_q90.glb V=10948 F=21876 bbox=([-64.13   6.84 -19.25]→[-59.05  14.26 -14.53]) level=0.0190
# [SHELL] chr14_24hrs_vacv_c1_q80.glb V=15439 F=30890 bbox=([-64.25   6.66 -19.4 ]→[-58.91  14.38 -14.41]) level=0.0081
# [SHELL] chr14_24hrs_vacv_c1_q60.glb V=17580 F=35160 bbox=([-64.45   6.43 -19.63]→[-58.71  14.58 -14.2 ]) level=0.0010
# [OK] chr14_24hrs_vacv_aligned.json: pts=1159 clusters=2 noise=0.25 mcs=20 ms=10
#
# === chr15 ===
# [DATA] chr15_12hrs_untr_aligned.json: JSON N=691  CSV N=691  (clustering on CSV; mapping by gene_name)
# [SHELL] chr15_12hrs_untr_c0_q95.glb V=4490 F=8928 bbox=([ 49.91   6.64 -28.65]→[ 53.69  10.89 -25.1 ]) level=0.0142
# [SHELL] chr15_12hrs_untr_c0_q90.glb V=6978 F=13936 bbox=([ 49.45   6.58 -28.73]→[ 53.81  11.01 -24.7 ]) level=0.0094
# [SHELL] chr15_12hrs_untr_c0_q80.glb V=9395 F=18798 bbox=([ 49.29   6.5  -28.82]→[ 53.94  11.13 -24.56]) level=0.0044
# [SHELL] chr15_12hrs_untr_c0_q60.glb V=9907 F=19814 bbox=([ 49.09   6.35 -29.01]→[ 54.15  11.33 -24.35]) level=0.0006
# [SHELL] chr15_12hrs_untr_c1_q95.glb V=7128 F=14196 bbox=([ 45.33   3.35 -32.56]→[ 50.58   9.99 -27.23]) level=0.0202
# [SHELL] chr15_12hrs_untr_c1_q90.glb V=11259 F=22490 bbox=([ 45.17   3.24 -32.63]→[ 50.68  10.08 -26.92]) level=0.0136
# [SHELL] chr15_12hrs_untr_c1_q80.glb V=15864 F=31780 bbox=([ 44.98   3.1  -32.71]→[ 50.94  10.25 -26.78]) level=0.0070
# [SHELL] chr15_12hrs_untr_c1_q60.glb V=15536 F=31064 bbox=([ 44.74   2.87 -32.9 ]→[ 51.2   10.5  -26.57]) level=0.0012
# [OK] chr15_12hrs_untr_aligned.json: pts=691 clusters=2 noise=0.07 mcs=19 ms=10
# [DATA] chr15_12hrs_vacv_aligned.json: JSON N=691  CSV N=691  (clustering on CSV; mapping by gene_name)
# [SHELL] chr15_12hrs_vacv_c0_q95.glb V=4272 F=8500 bbox=([41.82 -0.63 30.35]→[45.2   2.69 33.75]) level=0.0129
# [SHELL] chr15_12hrs_vacv_c0_q90.glb V=7096 F=14168 bbox=([41.75 -0.74 30.25]→[45.27  2.93 33.82]) level=0.0083
# [SHELL] chr15_12hrs_vacv_c0_q80.glb V=9684 F=19384 bbox=([41.66 -0.86 30.14]→[45.37  3.06 33.91]) level=0.0035
# [SHELL] chr15_12hrs_vacv_c0_q60.glb V=11334 F=22680 bbox=([41.5  -1.03 29.96]→[45.54  3.24 34.08]) level=0.0005
# [SHELL] chr15_12hrs_vacv_c1_q95.glb V=8762 F=17424 bbox=([37.04 -1.36 23.64]→[41.91  4.78 30.56]) level=0.0158
# [SHELL] chr15_12hrs_vacv_c1_q90.glb V=13984 F=27896 bbox=([36.99 -1.56 23.58]→[42.    4.86 30.66]) level=0.0101
# [SHELL] chr15_12hrs_vacv_c1_q80.glb V=19810 F=39650 bbox=([36.9  -1.71 23.45]→[42.1   4.96 30.78]) level=0.0047
# [SHELL] chr15_12hrs_vacv_c1_q60.glb V=22175 F=44382 bbox=([36.76 -1.92 23.26]→[42.29  5.15 30.98]) level=0.0007
# [OK] chr15_12hrs_vacv_aligned.json: pts=691 clusters=2 noise=0.17 mcs=19 ms=10
# [DATA] chr15_18hrs_untr_aligned.json: JSON N=691  CSV N=691  (clustering on CSV; mapping by gene_name)
# [SHELL] chr15_18hrs_untr_c0_q95.glb V=4422 F=8800 bbox=([ 36.06  14.15 -14.91]→[ 39.87  18.12 -11.59]) level=0.0124
# [SHELL] chr15_18hrs_untr_c0_q90.glb V=7298 F=14560 bbox=([ 35.74  14.1  -14.98]→[ 39.95  18.63 -11.49]) level=0.0073
# [SHELL] chr15_18hrs_untr_c0_q80.glb V=10024 F=20056 bbox=([ 35.61  14.   -15.08]→[ 40.06  18.76 -11.38]) level=0.0028
# ...
# [SHELL] chr6_18hrs_vacv_c6_q95.glb V=2624 F=5236 bbox=([ 22.23 -20.93 -47.15]→[ 24.62 -17.91 -44.92]) level=0.0316
# [SHELL] chr6_18hrs_vacv_c6_q90.glb V=3720 F=7436 bbox=([ 22.08 -21.03 -47.23]→[ 24.7  -17.32 -44.83]) level=0.0175
# [SHELL] chr6_18hrs_vacv_c6_q80.glb V=5300 F=10596 bbox=([ 21.86 -21.33 -47.34]→[ 24.81 -17.03 -44.72]) level=0.0055
# [SHELL] chr6_18hrs_vacv_c6_q60.glb V=7072 F=14140 bbox=([ 21.65 -21.55 -47.52]→[ 24.99 -16.81 -44.55]) level=0.0003
# [SHELL] chr6_18hrs_vacv_c7_q95.glb V=2874 F=5724 bbox=([ 18.97 -20.3  -43.91]→[ 22.98 -17.59 -42.19]) level=0.0154
# [SHELL] chr6_18hrs_vacv_c7_q90.glb V=4792 F=9572 bbox=([ 18.92 -20.36 -44.  ]→[ 23.29 -17.5  -42.13]) level=0.0082
# [SHELL] chr6_18hrs_vacv_c7_q80.glb V=6488 F=12972 bbox=([ 18.85 -20.44 -44.11]→[ 23.43 -17.41 -42.06]) level=0.0027
# [SHELL] chr6_18hrs_vacv_c7_q60.glb V=8838 F=17672 bbox=([ 18.68 -20.59 -44.27]→[ 23.6  -17.25 -41.9 ]) level=0.0002
# [SHELL] chr6_18hrs_vacv_c8_q95.glb V=1054 F=2104 bbox=([ 23.87 -19.63 -45.02]→[ 25.23 -18.5  -43.83]) level=0.0188
# [SHELL] chr6_18hrs_vacv_c8_q90.glb V=1552 F=3092 bbox=([ 23.6  -19.75 -45.09]→[ 25.3  -18.42 -43.75]) level=0.0095
# [SHELL] chr6_18hrs_vacv_c8_q80.glb V=2196 F=4388 bbox=([ 23.44 -19.88 -45.19]→[ 25.4  -18.3  -43.62]) level=0.0025
# [SHELL] chr6_18hrs_vacv_c8_q60.glb V=3270 F=6536 bbox=([ 23.26 -20.06 -45.37]→[ 25.57 -18.13 -43.44]) level=0.0001
# [SHELL] chr6_18hrs_vacv_c9_q95.glb V=1356 F=2704 bbox=([ 21.99 -20.55 -45.19]→[ 23.84 -18.17 -43.64]) level=0.0174
# [SHELL] chr6_18hrs_vacv_c9_q90.glb V=2108 F=4212 bbox=([ 21.92 -20.63 -45.28]→[ 24.07 -17.96 -43.48]) level=0.0079
# [SHELL] chr6_18hrs_vacv_c9_q80.glb V=3052 F=6100 bbox=([ 21.81 -20.77 -45.39]→[ 24.23 -17.8  -43.33]) level=0.0017
# [SHELL] chr6_18hrs_vacv_c9_q60.glb V=4456 F=8908 bbox=([ 21.67 -20.94 -45.55]→[ 24.41 -17.63 -43.16]) level=0.0001
# [SHELL] chr6_18hrs_vacv_c10_q95.glb V=1658 F=3300 bbox=([ 22.53 -18.53 -45.24]→[ 24.83 -15.94 -43.15]) level=0.0197
# [SHELL] chr6_18hrs_vacv_c10_q90.glb V=2486 F=4968 bbox=([ 22.47 -18.6  -45.31]→[ 24.92 -15.88 -43.07]) level=0.0107
# [SHELL] chr6_18hrs_vacv_c10_q80.glb V=3392 F=6780 bbox=([ 22.37 -18.72 -45.41]→[ 25.04 -15.78 -42.95]) level=0.0029
# [SHELL] chr6_18hrs_vacv_c10_q60.glb V=4822 F=9640 bbox=([ 22.21 -18.91 -45.57]→[ 25.22 -15.61 -42.75]) level=0.0001
# [OK] chr6_18hrs_vacv_aligned.json: pts=1639 clusters=11 noise=0.49 mcs=29 ms=14
# [DATA] chr6_24hrs_untr_aligned.json: JSON N=1639  CSV N=1639  (clustering on CSV; mapping by gene_name)
# [SHELL] chr6_24hrs_untr_c0_q95.glb V=5184 F=10332 bbox=([-48.25 -15.24  25.12]→[-44.03 -10.86  29.13]) level=0.0560
# [SHELL] chr6_24hrs_untr_c0_q90.glb V=7784 F=15564 bbox=([-48.35 -15.3   25.01]→[-43.78 -10.77  29.21]) level=0.0372
# [SHELL] chr6_24hrs_untr_c0_q80.glb V=10416 F=20848 bbox=([-48.48 -15.42  24.83]→[-43.6  -10.65  29.34]) level=0.0163
# [SHELL] chr6_24hrs_untr_c0_q60.glb V=11717 F=23442 bbox=([-48.69 -15.66  24.6 ]→[-43.28 -10.35  29.56]) level=0.0019
# [SHELL] chr6_24hrs_untr_c1_q95.glb V=1778 F=3532 bbox=([-45.41 -13.38  28.78]→[-43.82 -10.76  30.02]) level=0.0210
# [SHELL] chr6_24hrs_untr_c1_q90.glb V=2670 F=5332 bbox=([-45.5  -13.44  28.65]→[-43.72 -10.69  30.08]) level=0.0126
# [SHELL] chr6_24hrs_untr_c1_q80.glb V=3398 F=6788 bbox=([-45.61 -13.53  28.49]→[-43.57 -10.57  30.2 ]) level=0.0042
# [SHELL] chr6_24hrs_untr_c1_q60.glb V=4810 F=9616 bbox=([-45.79 -13.7   28.31]→[-43.39 -10.39  30.38]) level=0.0002
# [OK] chr6_24hrs_untr_aligned.json: pts=1639 clusters=2 noise=0.37 mcs=34 ms=None
# [DATA] chr6_24hrs_vacv_aligned.json: JSON N=1639  CSV N=1639  (clustering on CSV; mapping by gene_name)
# [SHELL] chr6_24hrs_vacv_c0_q95.glb V=1622 F=3236 bbox=([  9.18  20.55 -46.36]→[ 11.38  22.38 -45.05]) level=0.0161
# [SHELL] chr6_24hrs_vacv_c0_q90.glb V=2424 F=4840 bbox=([  9.11  20.46 -46.42]→[ 11.51  22.48 -44.85]) level=0.0082
# [SHELL] chr6_24hrs_vacv_c0_q80.glb V=3468 F=6932 bbox=([  9.    20.33 -46.51]→[ 11.66  22.6  -44.69]) level=0.0020
# [SHELL] chr6_24hrs_vacv_c0_q60.glb V=4934 F=9864 bbox=([  8.84  20.16 -46.67]→[ 11.84  22.76 -44.52]) level=0.0001
# [SHELL] chr6_24hrs_vacv_c1_q95.glb V=668 F=1332 bbox=([  8.95  24.27 -44.93]→[  9.69  25.14 -43.94]) level=0.0149
# [SHELL] chr6_24hrs_vacv_c1_q90.glb V=938 F=1872 bbox=([  8.87  24.2  -45.  ]→[  9.75  25.26 -43.87]) level=0.0072
# [SHELL] chr6_24hrs_vacv_c1_q80.glb V=1440 F=2876 bbox=([  8.77  24.08 -45.12]→[  9.84  25.39 -43.76]) level=0.0015
# [SHELL] chr6_24hrs_vacv_c1_q60.glb V=2194 F=4384 bbox=([  8.64  23.94 -45.26]→[  9.97  25.53 -43.63]) level=0.0001
# [SHELL] chr6_24hrs_vacv_c2_q95.glb V=694 F=1384 bbox=([  8.36  22.75 -45.06]→[  8.86  23.71 -43.94]) level=0.0139
# [SHELL] chr6_24hrs_vacv_c2_q90.glb V=1004 F=2004 bbox=([  8.27  22.69 -45.12]→[  8.93  23.83 -43.87]) level=0.0065
# [SHELL] chr6_24hrs_vacv_c2_q80.glb V=1508 F=3012 bbox=([  8.17  22.6  -45.21]→[  9.03  23.95 -43.78]) level=0.0014
# [SHELL] chr6_24hrs_vacv_c2_q60.glb V=2260 F=4516 bbox=([  8.04  22.48 -45.34]→[  9.15  24.09 -43.65]) level=0.0001
# [SHELL] chr6_24hrs_vacv_c3_q95.glb V=2454 F=4896 bbox=([ 11.25  22.21 -47.3 ]→[ 12.91  25.09 -45.13]) level=0.0196
# [SHELL] chr6_24hrs_vacv_c3_q90.glb V=3764 F=7516 bbox=([ 11.16  22.15 -47.36]→[ 12.98  25.24 -45.07]) level=0.0109
# [SHELL] chr6_24hrs_vacv_c3_q80.glb V=5146 F=10292 bbox=([ 11.05  22.07 -47.45]→[ 13.07  25.39 -44.93]) level=0.0036
# [SHELL] chr6_24hrs_vacv_c3_q60.glb V=7015 F=14038 bbox=([ 10.89  21.92 -47.61]→[ 13.23  25.56 -44.76]) level=0.0002
# [SHELL] chr6_24hrs_vacv_c4_q95.glb V=1431 F=2856 bbox=([  8.94  23.4  -44.15]→[ 11.06  24.63 -42.68]) level=0.0188
# [SHELL] chr6_24hrs_vacv_c4_q90.glb V=2090 F=4176 bbox=([  8.85  23.17 -44.27]→[ 11.13  24.71 -42.62]) level=0.0099
# [SHELL] chr6_24hrs_vacv_c4_q80.glb V=3040 F=6080 bbox=([  8.73  23.   -44.45]→[ 11.24  24.82 -42.52]) level=0.0026
# [SHELL] chr6_24hrs_vacv_c4_q60.glb V=4246 F=8492 bbox=([  8.56  22.81 -44.63]→[ 11.41  24.97 -42.38]) level=0.0001
# [SHELL] chr6_24hrs_vacv_c5_q95.glb V=1676 F=3348 bbox=([  9.66  21.93 -45.38]→[ 11.3   23.54 -43.06]) level=0.0240
# [SHELL] chr6_24hrs_vacv_c5_q90.glb V=2292 F=4580 bbox=([  9.42  21.82 -45.44]→[ 11.35  23.62 -42.99]) level=0.0134
# [SHELL] chr6_24hrs_vacv_c5_q80.glb V=3206 F=6408 bbox=([  9.29  21.7  -45.53]→[ 11.44  23.73 -42.89]) level=0.0038
# [SHELL] chr6_24hrs_vacv_c5_q60.glb V=4500 F=8996 bbox=([  9.1   21.52 -45.68]→[ 11.58  23.9  -42.74]) level=0.0002
# [SHELL] chr6_24hrs_vacv_c6_q95.glb V=1288 F=2564 bbox=([  9.22  22.85 -46.12]→[ 10.71  24.65 -44.6 ]) level=0.0199
# [SHELL] chr6_24hrs_vacv_c6_q90.glb V=1952 F=3900 bbox=([  9.08  22.78 -46.2 ]→[ 10.77  24.71 -44.53]) level=0.0104
# [SHELL] chr6_24hrs_vacv_c6_q80.glb V=2788 F=5572 bbox=([  8.91  22.69 -46.32]→[ 10.88  24.82 -44.42]) level=0.0027
# [SHELL] chr6_24hrs_vacv_c6_q60.glb V=3966 F=7928 bbox=([  8.72  22.53 -46.5 ]→[ 11.04  24.97 -44.25]) level=0.0001
# [SHELL] chr6_24hrs_vacv_c7_q95.glb V=958 F=1912 bbox=([ 11.67  25.67 -44.22]→[ 12.83  26.61 -42.92]) level=0.0176
# [SHELL] chr6_24hrs_vacv_c7_q90.glb V=1436 F=2864 bbox=([ 11.61  25.58 -44.52]→[ 12.93  26.69 -42.86]) level=0.0091
# [SHELL] chr6_24hrs_vacv_c7_q80.glb V=2135 F=4268 bbox=([ 11.5   25.48 -44.68]→[ 13.05  26.79 -42.76]) level=0.0023
# [SHELL] chr6_24hrs_vacv_c7_q60.glb V=3126 F=6252 bbox=([ 11.35  25.33 -44.85]→[ 13.21  26.94 -42.62]) level=0.0001
# [SHELL] chr6_24hrs_vacv_c8_q95.glb V=1442 F=2876 bbox=([ 11.21  24.51 -45.62]→[ 12.22  26.72 -43.88]) level=0.0159
# [SHELL] chr6_24hrs_vacv_c8_q90.glb V=2242 F=4476 bbox=([ 11.06  24.43 -45.7 ]→[ 12.37  26.91 -43.76]) level=0.0080
# [SHELL] chr6_24hrs_vacv_c8_q80.glb V=3218 F=6432 bbox=([ 10.92  24.29 -45.82]→[ 12.51  27.05 -43.63]) level=0.0021
# [SHELL] chr6_24hrs_vacv_c8_q60.glb V=4578 F=9152 bbox=([ 10.75  24.12 -45.98]→[ 12.67  27.22 -43.46]) level=0.0001
# [SHELL] chr6_24hrs_vacv_c9_q95.glb V=2290 F=4572 bbox=([ 11.83  22.86 -45.64]→[ 13.7   25.89 -43.59]) level=0.0398
# [SHELL] chr6_24hrs_vacv_c9_q90.glb V=3200 F=6396 bbox=([ 11.72  22.77 -45.72]→[ 13.77  25.96 -43.46]) level=0.0234
# [SHELL] chr6_24hrs_vacv_c9_q80.glb V=4501 F=9000 bbox=([ 11.59  22.65 -45.83]→[ 13.99  26.06 -43.3 ]) level=0.0070
# [SHELL] chr6_24hrs_vacv_c9_q60.glb V=6150 F=12304 bbox=([ 11.41  22.47 -46.01]→[ 14.22  26.23 -43.11]) level=0.0004
# [SHELL] chr6_24hrs_vacv_c10_q95.glb V=764 F=1528 bbox=([ 13.49  24.01 -47.14]→[ 14.54  25.24 -46.53]) level=0.0144
# [SHELL] chr6_24hrs_vacv_c10_q90.glb V=1110 F=2212 bbox=([ 13.42  23.88 -47.21]→[ 14.6   25.3  -46.28]) level=0.0065
# [SHELL] chr6_24hrs_vacv_c10_q80.glb V=1660 F=3316 bbox=([ 13.34  23.76 -47.29]→[ 14.68  25.39 -46.15]) level=0.0015
# [SHELL] chr6_24hrs_vacv_c10_q60.glb V=2464 F=4924 bbox=([ 13.2   23.61 -47.43]→[ 14.81  25.52 -46.01]) level=0.0001
# [SHELL] chr6_24hrs_vacv_c11_q95.glb V=1152 F=2300 bbox=([ 13.46  22.52 -46.31]→[ 14.4   24.25 -44.93]) level=0.0209
# [SHELL] chr6_24hrs_vacv_c11_q90.glb V=1718 F=3440 bbox=([ 13.38  22.45 -46.39]→[ 14.48  24.3  -44.88]) level=0.0113
# [SHELL] chr6_24hrs_vacv_c11_q80.glb V=2327 F=4652 bbox=([ 13.28  22.37 -46.48]→[ 14.59  24.39 -44.8 ]) level=0.0031
# [SHELL] chr6_24hrs_vacv_c11_q60.glb V=3356 F=6712 bbox=([ 13.13  22.22 -46.63]→[ 14.74  24.54 -44.66]) level=0.0002
# [OK] chr6_24hrs_vacv_aligned.json: pts=1639 clusters=12 noise=0.40 mcs=24 ms=12
#
# === chr7 ===
# [DATA] chr7_12hrs_untr_aligned.json: JSON N=843  CSV N=843  (clustering on CSV; mapping by gene_name)
# [SHELL] chr7_12hrs_untr_c0_q95.glb V=5602 F=11120 bbox=([ 42.88  21.23 -15.23]→[45.94 24.8  -9.47]) level=0.0106
# [SHELL] chr7_12hrs_untr_c0_q90.glb V=8335 F=16638 bbox=([ 42.81  21.17 -15.38]→[46.02 24.9  -9.36]) level=0.0067
# [SHELL] chr7_12hrs_untr_c0_q80.glb V=11306 F=22612 bbox=([ 42.71  21.08 -15.49]→[46.12 25.01 -9.24]) level=0.0027
# [SHELL] chr7_12hrs_untr_c0_q60.glb V=13838 F=27684 bbox=([ 42.55  20.92 -15.67]→[46.29 25.19 -9.07]) level=0.0003
# [SHELL] chr7_12hrs_untr_c1_q95.glb V=7220 F=14364 bbox=([ 41.36  19.42 -10.19]→[45.53 24.84 -1.48]) level=0.0165
# [SHELL] chr7_12hrs_untr_c1_q90.glb V=11247 F=22430 bbox=([ 41.28  19.33 -11.29]→[45.65 24.92 -1.41]) level=0.0108
# [SHELL] chr7_12hrs_untr_c1_q80.glb V=15730 F=31484 bbox=([ 41.18  19.2  -11.51]→[45.81 25.03 -1.31]) level=0.0050
# [SHELL] chr7_12hrs_untr_c1_q60.glb V=16591 F=33174 bbox=([ 40.98  19.   -11.74]→[46.03 25.23 -1.14]) level=0.0007
# [OK] chr7_12hrs_untr_aligned.json: pts=843 clusters=2 noise=0.40 mcs=17 ms=None
# [DATA] chr7_12hrs_vacv_aligned.json: JSON N=843  CSV N=843  (clustering on CSV; mapping by gene_name)
# [SHELL] chr7_12hrs_vacv_c0_q95.glb V=2480 F=4932 bbox=([-0.93 20.57 11.79]→[ 1.36 23.41 14.76]) level=0.0094
# [SHELL] chr7_12hrs_vacv_c0_q90.glb V=3616 F=7216 bbox=([-1.02 20.52 11.69]→[ 1.46 23.51 14.86]) level=0.0055
# [SHELL] chr7_12hrs_vacv_c0_q80.glb V=4804 F=9608 bbox=([-1.14 20.44 11.58]→[ 1.58 23.62 14.97]) level=0.0019
# [SHELL] chr7_12hrs_vacv_c0_q60.glb V=6214 F=12428 bbox=([-1.31 20.28 11.4 ]→[ 1.75 23.8  15.14]) level=0.0001
# [SHELL] chr7_12hrs_vacv_c1_q95.glb V=8056 F=16024 bbox=([-9.16 22.06  3.82]→[ 1.84 29.83 12.72]) level=0.0265
# [SHELL] chr7_12hrs_vacv_c1_q90.glb V=12497 F=24994 bbox=([-9.23 21.94  3.62]→[ 1.95 29.95 12.86]) level=0.0180
# [SHELL] chr7_12hrs_vacv_c1_q80.glb V=15974 F=31956 bbox=([-9.36 21.79  3.19]→[ 2.12 30.1  13.02]) level=0.0087
# [SHELL] chr7_12hrs_vacv_c1_q60.glb V=17203 F=34402 bbox=([-9.67 21.52  2.84]→[ 2.43 30.39 13.34]) level=0.0010
# [OK] chr7_12hrs_vacv_aligned.json: pts=843 clusters=2 noise=0.16 mcs=17 ms=8
# [DATA] chr7_18hrs_untr_aligned.json: JSON N=843  CSV N=843  (clustering on CSV; mapping by gene_name)
# [SHELL] chr7_18hrs_untr_c0_q95.glb V=2732 F=5408 bbox=([-49.93 -48.14   7.92]→[-45.49 -45.42  10.69]) level=0.0099
# [SHELL] chr7_18hrs_untr_c0_q90.glb V=4445 F=8874 bbox=([-50.06 -48.24   7.83]→[-45.39 -45.29  10.8 ]) level=0.0057
# [SHELL] chr7_18hrs_untr_c0_q80.glb V=6205 F=12410 bbox=([-50.18 -48.36   7.71]→[-45.27 -45.17  10.92]) level=0.0019
# [SHELL] chr7_18hrs_untr_c0_q60.glb V=8162 F=16320 bbox=([-50.36 -48.54   7.53]→[-45.09 -44.99  11.1 ]) level=0.0001
# [SHELL] chr7_18hrs_untr_c1_q95.glb V=5576 F=11092 bbox=([-53.11 -53.74   3.15]→[-48.36 -46.54   7.58]) level=0.0162
# [SHELL] chr7_18hrs_untr_c1_q90.glb V=8642 F=17224 bbox=([-53.25 -53.88   3.07]→[-48.27 -46.15   7.7 ]) level=0.0098
# [SHELL] chr7_18hrs_untr_c1_q80.glb V=12054 F=24096 bbox=([-53.39 -54.03   2.9 ]→[-48.15 -45.93   7.88]) level=0.0038
# [SHELL] chr7_18hrs_untr_c1_q60.glb V=15102 F=30208 bbox=([-53.61 -54.25   2.67]→[-47.95 -45.7    8.11]) level=0.0004
# [OK] chr7_18hrs_untr_aligned.json: pts=843 clusters=2 noise=0.59 mcs=54 ms=27
# [DATA] chr7_18hrs_vacv_aligned.json: JSON N=843  CSV N=843  (clustering on CSV; mapping by gene_name)
# [SHELL] chr7_18hrs_vacv_c0_q95.glb V=6746 F=13328 bbox=([ 20.4  -24.07  59.69]→[ 23.39 -20.08  66.83]) level=0.0097
# [SHELL] chr7_18hrs_vacv_c0_q90.glb V=11072 F=22092 bbox=([ 20.33 -24.16  59.59]→[ 23.43 -20.01  66.93]) level=0.0058
# [SHELL] chr7_18hrs_vacv_c0_q80.glb V=15877 F=31756 bbox=([ 20.25 -24.27  59.48]→[ 23.51 -19.9   67.04]) level=0.0023
# [SHELL] chr7_18hrs_vacv_c0_q60.glb V=18589 F=37182 bbox=([ 20.11 -24.42  59.32]→[ 23.66 -19.75  67.19]) level=0.0003
# [SHELL] chr7_18hrs_vacv_c1_q95.glb V=2884 F=5716 bbox=([ 21.28 -20.28  55.03]→[ 26.16 -17.22  59.04]) level=0.0087
# [SHELL] chr7_18hrs_vacv_c1_q90.glb V=4616 F=9204 bbox=([ 21.17 -20.39  54.94]→[ 26.27 -17.1   59.15]) level=0.0046
# [SHELL] chr7_18hrs_vacv_c1_q80.glb V=6612 F=13216 bbox=([ 21.04 -20.52  54.83]→[ 26.4  -16.98  59.28]) level=0.0013
# [SHELL] chr7_18hrs_vacv_c1_q60.glb V=8794 F=17580 bbox=([ 20.87 -20.69  54.66]→[ 26.57 -16.81  59.45]) level=0.0001
# [OK] chr7_18hrs_vacv_aligned.json: pts=843 clusters=2 noise=0.70 mcs=64 ms=None
# [DATA] chr7_24hrs_untr_aligned.json: JSON N=843  CSV N=843  (clustering on CSV; mapping by gene_name)
# [SHELL] chr7_24hrs_untr_c0_q95.glb V=1920 F=3808 bbox=([-45.43  31.96  22.7 ]→[-43.02  33.66  24.47]) level=0.0108
# [SHELL] chr7_24hrs_untr_c0_q90.glb V=2982 F=5960 bbox=([-45.49  31.82  22.57]→[-42.93  33.77  24.59]) level=0.0065
# [SHELL] chr7_24hrs_untr_c0_q80.glb V=3943 F=7884 bbox=([-45.57  31.71  22.46]→[-42.82  33.88  24.7 ]) level=0.0024
# [SHELL] chr7_24hrs_untr_c0_q60.glb V=5012 F=10024 bbox=([-45.73  31.54  22.29]→[-42.65  34.05  24.87]) level=0.0002
# [SHELL] chr7_24hrs_untr_c1_q95.glb V=8561 F=17026 bbox=([-46.62  28.73  23.45]→[-35.79  32.78  27.6 ]) level=0.0187
# [SHELL] chr7_24hrs_untr_c1_q90.glb V=13949 F=27850 bbox=([-46.69  28.22  23.39]→[-35.69  32.93  27.97]) level=0.0120
# [SHELL] chr7_24hrs_untr_c1_q80.glb V=20141 F=40310 bbox=([-46.79  28.06  23.3 ]→[-35.56  33.07  28.24]) level=0.0055
# [SHELL] chr7_24hrs_untr_c1_q60.glb V=22170 F=44332 bbox=([-46.98  27.84  23.11]→[-35.36  33.28  28.47]) level=0.0008
# [OK] chr7_24hrs_untr_aligned.json: pts=843 clusters=2 noise=0.31 mcs=17 ms=8
# [DATA] chr7_24hrs_vacv_aligned.json: JSON N=843  CSV N=843  (clustering on CSV; mapping by gene_name)
# [SHELL] chr7_24hrs_vacv_c0_q95.glb V=5326 F=10592 bbox=([ -3.52 110.07 -20.89]→[  2.33 113.28 -17.13]) level=0.0161
# [SHELL] chr7_24hrs_vacv_c0_q90.glb V=8481 F=16910 bbox=([ -4.33 109.25 -20.98]→[  2.41 113.45 -17.04]) level=0.0101
# [SHELL] chr7_24hrs_vacv_c0_q80.glb V=12426 F=24868 bbox=([ -4.53 109.07 -21.08]→[  2.51 113.59 -16.85]) level=0.0044
# [SHELL] chr7_24hrs_vacv_c0_q60.glb V=13589 F=27182 bbox=([ -4.73 108.87 -21.26]→[  2.69 113.78 -16.64]) level=0.0006
# [SHELL] chr7_24hrs_vacv_c1_q95.glb V=4642 F=9208 bbox=([ -7.2  103.47 -20.53]→[ -3.67 110.58 -17.43]) level=0.0108
# [SHELL] chr7_24hrs_vacv_c1_q90.glb V=7042 F=14060 bbox=([ -7.28 103.41 -20.58]→[ -3.57 110.64 -17.34]) level=0.0063
# [SHELL] chr7_24hrs_vacv_c1_q80.glb V=9982 F=19960 bbox=([ -7.39 103.3  -20.69]→[ -3.44 110.76 -17.22]) level=0.0022
# [SHELL] chr7_24hrs_vacv_c1_q60.glb V=12992 F=25980 bbox=([ -7.56 103.14 -20.86]→[ -3.27 110.93 -17.05]) level=0.0002
# [OK] chr7_24hrs_vacv_aligned.json: pts=843 clusters=2 noise=0.53 mcs=46 ms=23
#
# === Summary ===
# Completed chromosomes: 24
# Skipped chromosomes:   0
# Failures:              0
